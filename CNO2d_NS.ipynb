# %%
# !git clone https://github.com/camlab-ethz/ConvolutionalNeuralOperator.git
# Out:
# Cloning into 'ConvolutionalNeuralOperator'...
# remote: Enumerating objects: 496, done.
# remote: Counting objects: 100% (178/178), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 496 (delta 119), reused 87 (delta 87), pack-reused 318 (from 1)
# Receiving objects: 100% (496/496), 15.09 MiB | 11.96 MiB/s, done.
# Resolving deltas: 100% (219/219), done.

# %%
# %cd /content/ConvolutionalNeuralOperator/CNO2d_original_version
# Out:
# /content/ConvolutionalNeuralOperator/CNO2d_original_version

# %%
# %ls
# Out:
# CNOModule.py    Error_Distribution.py                    ModelSelectionCNO.py  torch_utils/
# debug_tools.py  Error_Distribution_VaryingResolution.py  Problems/             TrainCNO.py
# dnnlib/         LICENSE_NVIDIA.txt                       readme.md             training/

# %%
pip install ninja
# Out:
# Collecting ninja
#   Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1.4

# %%
import copy
import json
import os
import sys

import pandas as pd
import torch
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm

# %%
training_properties = {
    "learning_rate": 0.001,
    "weight_decay": 1e-6,
    "scheduler_step": 10,
    "scheduler_gamma": 0.98,
    "epochs": 1000,
    "batch_size": 16,
    "exp": 1,                # Do we use L1 or L2 errors? Default: L1
    "training_samples": 256  # How many training samples?
}
model_architecture_ = {

    #Parameters to be chosen with model selection:
    "N_layers": 3,            # Number of (D) & (U) blocks
    "channel_multiplier": 32, # Parameter d_e (how the number of channels changes)
    "N_res": 4,               # Number of (R) blocks in the middle networs.
    "N_res_neck" : 6,         # Number of (R) blocks in the BN

    #Other parameters:
    "in_size": 64,            # Resolution of the computational grid
    "retrain": 4,             # Random seed
    "kernel_size": 3,         # Kernel size.
    "FourierF": 0,            # Number of Fourier Features in the input channels. Default is 0.
    "activation": 'cno_lrelu',# cno_lrelu or cno_lrelu_torch or lrelu or

    #Filter properties:
    "cutoff_den": 2.0001,     # Cutoff parameter.
    "lrelu_upsampling": 2,    # Coefficient N_{\sigma}. Default is 2.
    "half_width_mult": 0.8,   # Coefficient c_h. Default is 1
    "filter_size": 6,         # 2xfilter_size is the number of taps N_{tap}. Default is 6.
    "radial_filter": 0,       # Is the filter radially symmetric? Default is 0 - NO.
}

# %%
folder = "/content/ConvolutionalNeuralOperator/CNO2d_original_version/TrainedModels"

# %%
if not os.path.isdir(folder):
    print("Generated new folder")
    os.mkdir(folder)
# Out:
# Generated new folder

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
writer = SummaryWriter(log_dir=folder) #usage of TensorBoard

learning_rate = training_properties["learning_rate"]
epochs = training_properties["epochs"]
batch_size = training_properties["batch_size"]
weight_decay = training_properties["weight_decay"]
scheduler_step = training_properties["scheduler_step"]
scheduler_gamma = training_properties["scheduler_gamma"]
training_samples = training_properties["training_samples"]
p = training_properties["exp"]

# %%
import torch.nn as nn

import torch
#from debug_tools import *
from training.filtered_networks import LReLu, LReLu_regular, LReLu_torch #Either "filtered LReLU" or regular LReLu
from debug_tools import format_tensor_size

# %%
class CNOBlock(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels,
                 in_size,
                 out_size,
                 cutoff_den = 2.0001,
                 conv_kernel = 3,
                 filter_size = 6,
                 lrelu_upsampling = 2,
                 half_width_mult  = 0.8,
                 radial = False,
                 batch_norm = True,
                 activation = 'cno_lrelu'
                 ):
        super(CNOBlock, self).__init__()

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.in_size  = in_size
        self.out_size = out_size
        self.conv_kernel = conv_kernel
        self.batch_norm = batch_norm

        #---------- Filter properties -----------
        self.citically_sampled = False #We use w_c = s/2.0001 --> NOT critically sampled

        if cutoff_den == 2.0:
            self.citically_sampled = True
        self.in_cutoff  = self.in_size / cutoff_den
        self.out_cutoff = self.out_size / cutoff_den

        self.in_halfwidth =  half_width_mult*self.in_size - self.in_size / cutoff_den
        self.out_halfwidth = half_width_mult*self.out_size - self.out_size / cutoff_den

        #-----------------------------------------

        # We apply Conv -> BN (optional) -> Activation
        # Up/Downsampling happens inside Activation

        pad = (self.conv_kernel-1)//2
        self.value_convolution = torch.nn.Conv2d(in_channels = self.in_channels, out_channels=self.out_channels,
                                           kernel_size=self.conv_kernel, stride = 1,
                                           padding = pad)
        self.gate_convolution = torch.nn.Conv2d(in_channels = self.in_channels, out_channels=self.out_channels,
                                           kernel_size=self.conv_kernel,
                                           padding = pad)

        if self.batch_norm:
            self.value_batch_norm  = nn.BatchNorm2d(self.out_channels)
            self.gate_batch_norm = nn.BatchNorm2d(self.out_channels)

        if activation == "cno_lrelu":
            self.activation  = LReLu(in_channels           = self.in_channels, #In _channels is not used in these settings
                                     out_channels          = self.out_channels,
                                     in_size               = self.in_size,
                                     out_size              = self.out_size,
                                     in_sampling_rate      = self.in_size,
                                     out_sampling_rate     = self.out_size,
                                     in_cutoff             = self.in_cutoff,
                                     out_cutoff            = self.out_cutoff,
                                     in_half_width         = self.in_halfwidth,
                                     out_half_width        = self.out_halfwidth,
                                     filter_size           = filter_size,
                                     lrelu_upsampling      = lrelu_upsampling,
                                     is_critically_sampled = self.citically_sampled,
                                     use_radial_filters    = False)
        elif activation == "cno_lrelu_torch":
            self.activation = LReLu_torch(in_channels           = self.out_channels, #In _channels is not used in these settings
                                            out_channels          = self.out_channels,
                                            in_size               = self.in_size,
                                            out_size              = self.out_size,
                                            in_sampling_rate      = self.in_size,
                                            out_sampling_rate     = self.out_size)
        elif activation == "lrelu":
            self.activation  = LReLu_regular(in_channels           = self.in_channels, #In _channels is not used in these settings
                                             out_channels          = self.out_channels,
                                             in_size               = self.in_size,
                                             out_size              = self.out_size,
                                             in_sampling_rate      = self.in_size,
                                             out_sampling_rate     = self.out_size)
        else:
            raise ValueError("Please specify different activation function")


    def forward(self, value_x, gate_x):
        value_x = self.convolution(value_x)
        gate_x = self.convolution(gate_x)
        if self.batch_norm:
            value_x = self.value_batch_norm(value_x)
            gate_x = self.gate_batch_norm(gate_x)
        value_x = value_x * torch.sigmoid(gate_x)

        return value_x, gate_x

#------------------------------------------------------------------------------

# Contains CNOBlock -> Convolution -> BN

class LiftProjectBlock(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels,
                 in_size,
                 out_size,
                 latent_dim = 64,
                 cutoff_den = 2.0001,
                 conv_kernel = 3,
                 filter_size = 6,
                 lrelu_upsampling = 2,
                 half_width_mult  = 0.8,
                 radial = False,
                 batch_norm = True,
                 activation = 'cno_lrelu'
                 ):
        super(LiftProjectBlock, self).__init__()

        self.inter_CNOBlock = CNOBlock(in_channels = in_channels,
                                    out_channels = latent_dim,
                                    in_size = in_size,
                                    out_size = out_size,
                                    cutoff_den = cutoff_den,
                                    conv_kernel = conv_kernel,
                                    filter_size = filter_size,
                                    lrelu_upsampling = lrelu_upsampling,
                                    half_width_mult  = half_width_mult,
                                    radial = radial,
                                    batch_norm = batch_norm,
                                    activation = activation)

        pad = (conv_kernel-1)//2
        self.value_convolution = torch.nn.Conv2d(in_channels = latent_dim, out_channels=out_channels,
                                           kernel_size=conv_kernel, stride = 1,
                                           padding = pad)
        self.gate_convolution = torch.nn.Conv2d(in_channels = latent_dim, out_channels=out_channels,
                                           kernel_size=conv_kernel, stride = 1,
                                           padding = pad)

        self.batch_norm = batch_norm
        if self.batch_norm:
            self.value_batch_norm  = nn.BatchNorm2d(out_channels)
            self.gate_batch_norm = nn.BatchNorm2d(out_channels)

    def forward(self, value_x, gate_x):
        value_x, gate_x = self.inter_CNOBlock(value_x, gate_x)

        value_x = self.value_convolution(value_x)
        gate_x = self.gate_convolution(gate_x)
        if self.batch_norm:
            value_x = self.batch_norm(value_x)
            gate_x = self.batch_norm(gate_x)
        return value_x, gate_x

#------------------------------------------------------------------------------

# Residual Block containts:
    # Convolution -> BN -> Activation -> Convolution -> BN -> SKIP CONNECTION

class ResidualBlock(nn.Module):
    def __init__(self,
                 channels,
                 size,
                 cutoff_den = 2.0001,
                 conv_kernel = 3,
                 filter_size = 6,
                 lrelu_upsampling = 2,
                 half_width_mult  = 0.8,
                 radial = False,
                 batch_norm = True,
                 activation = 'cno_lrelu'
                 ):
        super(ResidualBlock, self).__init__()

        self.channels = channels
        self.size  = size
        self.conv_kernel = conv_kernel
        self.batch_norm = batch_norm

        #---------- Filter properties -----------
        self.citically_sampled = False #We use w_c = s/2.0001 --> NOT critically sampled

        if cutoff_den == 2.0:
            self.citically_sampled = True
        self.cutoff  = self.size / cutoff_den
        self.halfwidth =  half_width_mult*self.size - self.size / cutoff_den

        #-----------------------------------------

        pad = (self.conv_kernel-1)//2
        self.value_convolution1 = torch.nn.Conv2d(in_channels = self.channels, out_channels=self.channels,
                                           kernel_size=self.conv_kernel, stride = 1,
                                           padding = pad)
        self.value_convolution2 = torch.nn.Conv2d(in_channels = self.channels, out_channels=self.channels,
                                           kernel_size=self.conv_kernel, stride = 1,
                                           padding = pad)
        self.gate_convolution1 = torch.nn.Conv2d(in_channels = self.channels, out_channels=self.channels,
                                           kernel_size=self.conv_kernel, stride = 1,
                                           padding = pad)
        self.gate_convolution2 = torch.nn.Conv2d(in_channels = self.channels, out_channels=self.channels,
                                           kernel_size=self.conv_kernel, stride = 1,
                                           padding = pad)

        if self.batch_norm:
            self.value_batch_norm1  = nn.BatchNorm2d(self.channels)
            self.value_batch_norm2  = nn.BatchNorm2d(self.channels)
            self.gate_batch_norm1  = nn.BatchNorm2d(self.channels)
            self.gate_batch_norm2  = nn.BatchNorm2d(self.channels)

        if activation == "cno_lrelu":

            self.activation  = LReLu(in_channels           = self.channels, #In _channels is not used in these settings
                                     out_channels          = self.channels,
                                     in_size               = self.size,
                                     out_size              = self.size,
                                     in_sampling_rate      = self.size,
                                     out_sampling_rate     = self.size,
                                     in_cutoff             = self.cutoff,
                                     out_cutoff            = self.cutoff,
                                     in_half_width         = self.halfwidth,
                                     out_half_width        = self.halfwidth,
                                     filter_size           = filter_size,
                                     lrelu_upsampling      = lrelu_upsampling,
                                     is_critically_sampled = self.citically_sampled,
                                     use_radial_filters    = False)

        elif activation == "cno_lrelu_torch":
            self.activation = LReLu_torch(in_channels           = self.channels, #In _channels is not used in these settings
                                            out_channels          = self.channels,
                                            in_size               = self.size,
                                            out_size              = self.size,
                                            in_sampling_rate      = self.size,
                                            out_sampling_rate     = self.size)
        elif activation == "lrelu":

            self.activation = LReLu_regular(in_channels           = self.channels, #In _channels is not used in these settings
                                            out_channels          = self.channels,
                                            in_size               = self.size,
                                            out_size              = self.size,
                                            in_sampling_rate      = self.size,
                                            out_sampling_rate     = self.size)
        else:
            raise ValueError("Please specify different activation function")


    def forward(self, value_x, gate_x):
        value_out = self.value_convolution1(value_x)
        gate_out = self.gate_convolution1(gate_x)
        if self.batch_norm:
            value_out = self.value_batch_norm1(value_out)
            gate_out = self.gate_batch_norm1(gate_out)
        value_out = value_out * torch.sigmoid(gate_out)
        value_out = self.value_convolution2(value_out)
        gate_out = self.gate_convolution2(gate_out)
        if self.batch_norm:
            value_out = self.value_batch_norm2(value_out)
            gate_out = self.gate_batch_norm2(gate_out)

        return value_x + value_out, gate_x + gate_out
#------------------------------------------------------------------------------

#CNO NETWORK:
class CNO(nn.Module):
    def __init__(self,
                 in_dim,                    # Number of input channels.
                 in_size,                   # Input spatial size
                 N_layers,                  # Number of (D) or (U) blocks in the network
                 N_res = 1,                 # Number of (R) blocks per level (except the neck)
                 N_res_neck = 6,            # Number of (R) blocks in the neck
                 channel_multiplier = 32,   # How the number of channels evolve?
                 conv_kernel=3,             # Size of all the kernels
                 cutoff_den = 2.0001,       # Filter property 1.
                 filter_size=6,             # Filter property 2.
                 lrelu_upsampling = 2,      # Filter property 3.
                 half_width_mult  = 0.8,    # Filter property 4.
                 radial = False,            # Filter property 5. Is filter radial?
                 batch_norm = True,         # Add BN? We do not add BN in lifting/projection layer
                 out_dim = 1,               # Target dimension
                 out_size = 1,              # If out_size is 1, Then out_size = in_size. Else must be int
                 expand_input = False,      # Start with original in_size, or expand it (pad zeros in the spectrum)
                 latent_lift_proj_dim = 64, # Intermediate latent dimension in the lifting/projection layer
                 add_inv = True,            # Add invariant block (I) after the intermediate connections?
                 activation = 'cno_lrelu'   # Activation function can be 'cno_lrelu' or 'lrelu'
                ):

        super(CNO, self).__init__()

        ###################### Define the parameters & specifications #################################################


        # Number of (D) & (U) Blocks
        self.N_layers = int(N_layers)

        # Input is lifted to the half on channel_multiplier dimension
        self.lift_dim = channel_multiplier//2
        self.out_dim  = out_dim

        #Should we add invariant layers in the decoder?
        self.add_inv = add_inv

        # The growth of the channels : d_e parametee
        self.channel_multiplier = channel_multiplier

        # Is the filter radial? We always use NOT radial
        if radial ==0:
            self.radial = False
        else:
            self.radial = True

        ###################### Define evolution of the number features ################################################

        # How the features in Encoder evolve (number of features)
        self.encoder_features = [self.lift_dim]
        for i in range(self.N_layers):
            self.encoder_features.append(2 ** i *   self.channel_multiplier)

        # How the features in Decoder evolve (number of features)
        self.decoder_features_in = self.encoder_features[1:]
        self.decoder_features_in.reverse()
        self.decoder_features_out = self.encoder_features[:-1]
        self.decoder_features_out.reverse()

        for i in range(1, self.N_layers):
            self.decoder_features_in[i] = 2*self.decoder_features_in[i] #Pad the outputs of the resnets

        self.inv_features = self.decoder_features_in
        self.inv_features.append(self.encoder_features[0] + self.decoder_features_out[-1])

        ###################### Define evolution of sampling rates #####################################################

        if not expand_input:
            latent_size = in_size # No change in in_size
        else:
            down_exponent = 2 ** N_layers
            latent_size = in_size - (in_size % down_exponent) + down_exponent # Jump from 64 to 72, for example

        #Are inputs and outputs of the same size? If not, how should the size of the decoder evolve?
        if out_size == 1:
            latent_size_out = latent_size
        else:
            if not expand_input:
                latent_size_out = out_size # No change in in_size
            else:
                down_exponent = 2 ** N_layers
                latent_size_out = out_size - (out_size % down_exponent) + down_exponent # Jump from 64 to 72, for example

        self.encoder_sizes = []
        self.decoder_sizes = []
        for i in range(self.N_layers + 1):
            self.encoder_sizes.append(latent_size // 2 ** i)
            self.decoder_sizes.append(latent_size_out // 2 ** (self.N_layers - i))



        ###################### Define Projection & Lift ##############################################################

        self.lift = LiftProjectBlock(in_channels  = in_dim,
                                     out_channels = self.encoder_features[0],
                                     in_size      = in_size,
                                     out_size     = self.encoder_sizes[0],
                                     latent_dim   = latent_lift_proj_dim,
                                     cutoff_den   = cutoff_den,
                                     conv_kernel  = conv_kernel,
                                     filter_size  = filter_size,
                                     lrelu_upsampling  = lrelu_upsampling,
                                     half_width_mult   = half_width_mult,
                                     radial            = radial,
                                     batch_norm        = False,
                                     activation = activation)
        _out_size = out_size
        if out_size == 1:
            _out_size = in_size

        self.project = LiftProjectBlock(in_channels  = self.encoder_features[0] + self.decoder_features_out[-1],
                                        out_channels = out_dim,
                                        in_size      = self.decoder_sizes[-1],
                                        out_size     = _out_size,
                                        latent_dim   = latent_lift_proj_dim,
                                        cutoff_den   = cutoff_den,
                                        conv_kernel  = conv_kernel,
                                        filter_size  = filter_size,
                                        lrelu_upsampling  = lrelu_upsampling,
                                        half_width_mult   = half_width_mult,
                                        radial            = radial,
                                        batch_norm        = False,
                                        activation = activation)

        ###################### Define U & D blocks ###################################################################

        self.encoder         = nn.ModuleList([(CNOBlock(in_channels  = self.encoder_features[i],
                                                        out_channels = self.encoder_features[i+1],
                                                        in_size      = self.encoder_sizes[i],
                                                        out_size     = self.encoder_sizes[i+1],
                                                        cutoff_den   = cutoff_den,
                                                        conv_kernel  = conv_kernel,
                                                        filter_size  = filter_size,
                                                        lrelu_upsampling = lrelu_upsampling,
                                                        half_width_mult  = half_width_mult,
                                                        radial = radial,
                                                        batch_norm = batch_norm,
                                                        activation = activation))
                                               for i in range(self.N_layers)])

        # After the ResNets are executed, the sizes of encoder and decoder might not match (if out_size>1)
        # We must ensure that the sizes are the same, by aplying CNO Blocks
        self.ED_expansion     = nn.ModuleList([(CNOBlock(in_channels = self.encoder_features[i],
                                                        out_channels = self.encoder_features[i],
                                                        in_size      = self.encoder_sizes[i],
                                                        out_size     = self.decoder_sizes[self.N_layers - i],
                                                        cutoff_den   = cutoff_den,
                                                        conv_kernel  = conv_kernel,
                                                        filter_size  = filter_size,
                                                        lrelu_upsampling = lrelu_upsampling,
                                                        half_width_mult  = half_width_mult,
                                                        radial = radial,
                                                        batch_norm = batch_norm,
                                                        activation = activation))
                                               for i in range(self.N_layers + 1)])

        self.decoder         = nn.ModuleList([(CNOBlock(in_channels  = self.decoder_features_in[i],
                                                        out_channels = self.decoder_features_out[i],
                                                        in_size      = self.decoder_sizes[i],
                                                        out_size     = self.decoder_sizes[i+1],
                                                        cutoff_den   = cutoff_den,
                                                        conv_kernel  = conv_kernel,
                                                        filter_size  = filter_size,
                                                        lrelu_upsampling = lrelu_upsampling,
                                                        half_width_mult  = half_width_mult,
                                                        radial = radial,
                                                        batch_norm = batch_norm,
                                                        activation = activation))
                                               for i in range(self.N_layers)])


        self.decoder_inv    = nn.ModuleList([(CNOBlock(in_channels  =  self.inv_features[i],
                                                        out_channels = self.inv_features[i],
                                                        in_size      = self.decoder_sizes[i],
                                                        out_size     = self.decoder_sizes[i],
                                                        cutoff_den   = cutoff_den,
                                                        conv_kernel  = conv_kernel,
                                                        filter_size  = filter_size,
                                                        lrelu_upsampling = lrelu_upsampling,
                                                        half_width_mult  = half_width_mult,
                                                        radial = radial,
                                                        batch_norm = batch_norm,
                                                        activation = activation))
                                               for i in range(self.N_layers + 1)])


        ####################### Define ResNets Blocks ################################################################

        # Here, we define ResNet Blocks.
        # We also define the BatchNorm layers applied BEFORE the ResNet blocks

        # Operator UNet:
        # Outputs of the middle networks are patched (or padded) to corresponding sets of feature maps in the decoder

        self.res_nets = []
        self.N_res = int(N_res)
        self.N_res_neck = int(N_res_neck)

        # Define the ResNet blocks & BatchNorm
        for l in range(self.N_layers):
            for i in range(self.N_res):
                self.res_nets.append(ResidualBlock(channels = self.encoder_features[l],
                                                   size     = self.encoder_sizes[l],
                                                   cutoff_den = cutoff_den,
                                                   conv_kernel = conv_kernel,
                                                   filter_size = filter_size,
                                                   lrelu_upsampling = lrelu_upsampling,
                                                   half_width_mult  = half_width_mult,
                                                   radial = radial,
                                                   batch_norm = batch_norm,
                                                   activation = activation))
        for i in range(self.N_res_neck):
            self.res_nets.append(ResidualBlock(channels = self.encoder_features[self.N_layers],
                                               size     = self.encoder_sizes[self.N_layers],
                                               cutoff_den = cutoff_den,
                                               conv_kernel = conv_kernel,
                                               filter_size = filter_size,
                                               lrelu_upsampling = lrelu_upsampling,
                                               half_width_mult  = half_width_mult,
                                               radial = radial,
                                               batch_norm = batch_norm,
                                               activation = activation))

        self.res_nets = torch.nn.Sequential(*self.res_nets)


    def forward(self, x):
        gate_x = x
        value_x = torch.ones_like(x)

        #Execute Lift ---------------------------------------------------------
        value_x = self.lift(value_x, gate_x)
        skip = []

        # Execute Encoder -----------------------------------------------------
        for i in range(self.N_layers):

            #Apply ResNet & save the result
            for j in range(self.N_res):
                value_x, gate_x = self.res_nets[i*self.N_res + j](value_x, gate_x)
            skip.append([value_x, gate_x])

            # Apply (D) block
            value_x, gate_x = self.encoder[i](value_x, gate_x)

        #----------------------------------------------------------------------

        # Apply the deepest ResNet (bottle neck)
        for j in range(self.N_res_neck):
            value_x, gate_x = self.res_nets[-j-1](value_x, gate_)

        # Execute Decoder -----------------------------------------------------
        for i in range(self.N_layers):

            # Apply (I) block (ED_expansion) & cat if needed
            if i == 0:
                value_x, gate_x = self.ED_expansion[self.N_layers - i](value_x, gate_x) #BottleNeck : no cat
            else:
                value_x = torch.cat((value_x, self.ED_expansion[self.N_layers - i](skip[-i][0], skip[-i][1])[0]),1)
                gate_x = torch.cat((gate_x, self.ED_expansion[self.N_layers - i](skip[-i][0], skip[-i][1])[1]),1)

            if self.add_inv:
                value_x, gate_x = self.decoder_inv[i](value_x, gate_)
            # Apply (U) block
            value_x, gate_x = self.decoder[i](value_x, gate_x)
        # Cat & Execute Projetion ---------------------------------------------

        value_x = torch.cat((value_x, self.ED_expansion[0](skip[0][0], skip[0][1])[0]),1)
        gate_x = torch.cat((gate_x, self.ED_expansion[0](skip[0][0], skip[0][1])[1]),1)

        value_x, gate_x = self.project(value_x, gate_x)

        del skip
        del y

        return value_x


    def get_n_params(self):
        pp = 0

        for p in list(self.parameters()):
            nn = 1
            for s in list(p.size()):
                nn = nn * s
            pp += nn
        return pp

    def print_size(self):
        nparams = 0
        nbytes = 0

        for param in self.parameters():
            nparams += param.numel()
            nbytes += param.data.element_size() * param.numel()

        print(f'Total number of model parameters: {nparams} (~{format_tensor_size(nbytes)})')

        return nparams

# %%
import random

import h5py
import numpy as np
import torch
from torch.utils.data import DataLoader

from CNOModule import CNO
from torch.utils.data import Dataset

import scipy

from training.FourierFeatures import FourierFeatures

torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %%
def samples_fft(u):
    return scipy.fft.fft2(u, norm='forward', workers=-1)

def samples_ifft(u_hat):
    return scipy.fft.ifft2(u_hat, norm='forward', workers=-1).real

def downsample(u, N):
    N_old = u.shape[-2]
    freqs = scipy.fft.fftfreq(N_old, d=1/N_old)
    sel = np.logical_and(freqs >= -N/2, freqs <= N/2-1)
    u_hat = samples_fft(u)
    u_hat_down = u_hat[:,:,sel,:][:,:,:,sel]
    u_down = samples_ifft(u_hat_down)
    return u_down

#------------------------------------------------------------------------------

#Load default parameters:

def default_param(network_properties):

    if "channel_multiplier" not in network_properties:
        network_properties["channel_multiplier"] = 32

    if "half_width_mult" not in network_properties:
        network_properties["half_width_mult"] = 1

    if "lrelu_upsampling" not in network_properties:
        network_properties["lrelu_upsampling"] = 2

    if "filter_size" not in network_properties:
        network_properties["filter_size"] = 6

    if "out_size" not in network_properties:
        network_properties["out_size"] = 1

    if "radial" not in network_properties:
        network_properties["radial_filter"] = 0

    if "cutoff_den" not in network_properties:
        network_properties["cutoff_den"] = 2.0001

    if "FourierF" not in network_properties:
        network_properties["FourierF"] = 0

    if "retrain" not in network_properties:
        network_properties["retrain"] = 4

    if "kernel_size" not in network_properties:
        network_properties["kernel_size"] = 3

    if "activation" not in network_properties:
        network_properties["activation"] = 'cno_lrelu'

    return network_properties

# %%
class ShearLayerDataset(Dataset):
    def __init__(self, which="training", nf=0, training_samples = 750, s=64, in_dist = True):

        self.s = s
        self.in_dist = in_dist
        #The file:

        if in_dist:
            if self.s==64:
                self.file_data = "/content/drive/MyDrive/PDE Datasets - 2/data/NavierStokes_64x64_IN.h5" #In-distribution file 64x64
            else:
                self.file_data = "/content/drive/MyDrive/PDE Datasets - 2/data/NavierStokes_128x128_IN.h5"   #In-distribution file 128x128
        else:
            self.file_data = "/content/drive/MyDrive/PDE Datasets - 2/data/NavierStokes_128x128_OUT.h5"  #Out-of_-distribution file 128x128

        self.reader = h5py.File(self.file_data, 'r')
        self.N_max = 1024

        self.n_val  = 128
        self.n_test = 128
        self.min_data = 1.4307903051376343
        self.max_data = -1.4307903051376343
        self.min_model = 2.0603253841400146
        self.max_model= -2.0383243560791016

        if which == "training":
            self.length = training_samples
            self.start = 0
        elif which == "validation":
            self.length = self.n_val
            self.start = self.N_max - self.n_val - self.n_test
        elif which == "test":
            self.length = self.n_test
            self.start = self.N_max  - self.n_test

        #Fourier modes (Default is 0):
        self.N_Fourier_F = nf

    def __len__(self):
        return self.length

    def __getitem__(self, index):

        if self.s == 64 and self.in_dist:
            inputs = torch.from_numpy(self.reader['Sample_' + str(index + self.start)]["input"][:]).type(torch.float32).reshape(1, self.s, self.s)
            labels = torch.from_numpy(self.reader['Sample_' + str(index + self.start)]["output"][:]).type(torch.float32).reshape(1, self.s, self.s)

        else:

            inputs = self.reader['Sample_' + str(index + self.start)]["input"][:].reshape(1,1,self.s, self.s)
            labels = self.reader['Sample_' + str(index + self.start)]["output"][:].reshape(1,1, self.s, self.s)

            if self.s<128:
                inputs = downsample(inputs, self.s).reshape(1, self.s, self.s)
                labels = downsample(labels, self.s).reshape(1, self.s, self.s)
            else:
                inputs = inputs.reshape(1, 128, 128)
                labels = labels.reshape(1, 128, 128)

            inputs = torch.from_numpy(inputs).type(torch.float32)
            labels = torch.from_numpy(labels).type(torch.float32)

        inputs = (inputs - self.min_data)/(self.max_data - self.min_data)
        labels = (labels - self.min_model)/(self.max_model - self.min_model)


        if self.N_Fourier_F > 0:
            grid = self.get_grid()
            FF = FourierFeatures(1, self.N_Fourier_F, grid.device)
            ff_grid = FF(grid)
            ff_grid = ff_grid.permute(2, 0, 1)
            inputs = torch.cat((inputs, ff_grid), 0)

        return inputs, labels

    def get_grid(self):
        x = torch.linspace(0, 1, self.s)
        y = torch.linspace(0, 1, self.s)
        x_grid, y_grid = torch.meshgrid(x, y)
        x_grid = x_grid.unsqueeze(-1)
        y_grid = y_grid.unsqueeze(-1)
        grid = torch.cat((x_grid, y_grid), -1)
        return grid

class ShearLayer:
    def __init__(self, network_properties, device, batch_size, training_samples, size, in_dist = True):

        #Must have parameters: ------------------------------------------------

        if "in_size" in network_properties:
            self.in_size = network_properties["in_size"]
            assert self.in_size<=128
        else:
            raise ValueError("You must specify the computational grid size.")

        if "N_layers" in network_properties:
            N_layers = network_properties["N_layers"]
        else:
            raise ValueError("You must specify the number of (D) + (U) blocks.")

        if "N_res" in network_properties:
                N_res = network_properties["N_res"]
        else:
            raise ValueError("You must specify the number of (R) blocks.")

        if "N_res_neck" in network_properties:
                N_res_neck = network_properties["N_res_neck"]
        else:
            raise ValueError("You must specify the number of (R)-neck blocks.")

        #Load default parameters if they are not in network_properties
        network_properties = default_param(network_properties)

        #----------------------------------------------------------------------
        kernel_size = network_properties["kernel_size"]
        channel_multiplier = network_properties["channel_multiplier"]
        retrain = network_properties["retrain"]
        self.N_Fourier_F = network_properties["FourierF"]

        #Filter properties: ---------------------------------------------------
        cutoff_den = network_properties["cutoff_den"]
        filter_size = network_properties["filter_size"]
        half_width_mult = network_properties["half_width_mult"]
        lrelu_upsampling = network_properties["lrelu_upsampling"]
        activation = network_properties["activation"]
        ##----------------------------------------------------------------------

        torch.manual_seed(retrain)

        self.model = CNO(in_dim  = 1 + 2*self.N_Fourier_F,     # Number of input channels.
                        in_size = self.in_size,                # Input spatial size
                        N_layers = N_layers,                   # Number of (D) and (U) Blocks in the network
                        N_res = N_res,                         # Number of (R) Blocks per level
                        N_res_neck = N_res_neck,
                        channel_multiplier = channel_multiplier,
                        conv_kernel=kernel_size,
                        cutoff_den = cutoff_den,
                        filter_size=filter_size,
                        lrelu_upsampling = lrelu_upsampling,
                        half_width_mult  = half_width_mult,
                        activation = activation).to(device)

        #----------------------------------------------------------------------

        #Change number of workers accoirding to your preference

        num_workers = 0
        self.train_loader = DataLoader(ShearLayerDataset("training", self.N_Fourier_F, training_samples, size), batch_size=batch_size, shuffle=True, num_workers=num_workers)
        self.val_loader = DataLoader(ShearLayerDataset("validation", self.N_Fourier_F, training_samples, size), batch_size=batch_size, shuffle=False, num_workers=num_workers)
        self.test_loader = DataLoader(ShearLayerDataset("test", self.N_Fourier_F, training_samples, size, in_dist), batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
example = ShearLayer(model_architecture_, device, batch_size, training_samples, size = 64)

# %%
model = example.model
n_params = model.print_size()
train_loader = example.train_loader #TRAIN LOADER
val_loader = example.val_loader #VALIDATION LOADER

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step, gamma=scheduler_gamma)
freq_print = 1
# Out:
# Total number of model parameters: 2951249 (~11.26MiB)

# %%
if p == 1:
    loss = torch.nn.L1Loss()
elif p == 2:
    loss = torch.nn.MSELoss()

best_model_testing_error = 1000 #Save the model once it has less than 1000% relative L1 error
patience = int(0.2 * epochs)    # Early stopping parameter
counter = 0

# %%
for epoch in range(epochs):
    with tqdm(unit="batch", disable=False) as tepoch:

        model.train()
        tepoch.set_description(f"Epoch {epoch}")
        train_mse = 0.0
        running_relative_train_mse = 0.0
        for step, (input_batch, output_batch) in enumerate(train_loader):
            optimizer.zero_grad()
            input_batch = input_batch.to(device)
            output_batch = output_batch.to(device)

            output_pred_batch = model(input_batch)

            loss_f = loss(output_pred_batch, output_batch) / loss(torch.zeros_like(output_batch).to(device), output_batch)

            loss_f.backward()
            optimizer.step()
            train_mse = train_mse * step / (step + 1) + loss_f.item() / (step + 1)
            tepoch.set_postfix({'Batch': step + 1, 'Train loss (in progress)': train_mse})

        writer.add_scalar("train_loss/train_loss", train_mse, epoch)

        with torch.no_grad():
            model.eval()
            test_relative_l2 = 0.0
            train_relative_l2 = 0.0

            for step, (input_batch, output_batch) in enumerate(val_loader):

                input_batch = input_batch.to(device)
                output_batch = output_batch.to(device)
                output_pred_batch = model(input_batch)

                loss_f = torch.mean(abs(output_pred_batch - output_batch)) / torch.mean(abs(output_batch)) * 100
                test_relative_l2 += loss_f.item()
            test_relative_l2 /= len(val_loader)

            for step, (input_batch, output_batch) in enumerate(train_loader):
                input_batch = input_batch.to(device)
                output_batch = output_batch.to(device)
                output_pred_batch = model(input_batch)
            train_relative_l2 /= len(train_loader)

            writer.add_scalar("train_loss/train_loss_rel", train_relative_l2, epoch)
            writer.add_scalar("val_loss/val_loss", test_relative_l2, epoch)

            if test_relative_l2 < best_model_testing_error:
                best_model_testing_error = test_relative_l2
                best_model = copy.deepcopy(model)
                torch.save(best_model, folder + "/model.pkl")
                writer.add_scalar("val_loss/Best Relative Testing Error", best_model_testing_error, epoch)
                counter = 0
            else:
                counter+=1

        tepoch.set_postfix({'Train loss': train_mse, "Relative Train": train_relative_l2, "Relative Val loss": test_relative_l2})
        tepoch.close()

        with open(folder + '/errors.txt', 'w') as file:
            file.write("Training Error: " + str(train_mse) + "\n")
            file.write("Best Testing Error: " + str(best_model_testing_error) + "\n")
            file.write("Current Epoch: " + str(epoch) + "\n")
            file.write("Params: " + str(n_params) + "\n")
        scheduler.step()

    if counter>patience:
        print("Early Stopping")
        break
# Out:
# Epoch 0: : 0batch [00:00, ?batch/s]
# Setting up PyTorch plugin "filtered_lrelu_plugin"...
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:2059: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Done.
# Epoch 0: : 0batch [02:37, ?batch/s, Train loss=0.307, Relative Train=0, Relative Val loss=29]
# Epoch 1: : 0batch [00:01, ?batch/s, Train loss=0.131, Relative Train=0, Relative Val loss=17.8]
# Epoch 2: : 0batch [00:02, ?batch/s, Train loss=0.122, Relative Train=0, Relative Val loss=15.6]
# Epoch 3: : 0batch [00:02, ?batch/s, Train loss=0.119, Relative Train=0, Relative Val loss=13]
# Epoch 4: : 0batch [00:01, ?batch/s, Train loss=0.123, Relative Train=0, Relative Val loss=12]
# Epoch 5: : 0batch [00:01, ?batch/s, Train loss=0.13, Relative Train=0, Relative Val loss=13.4]
# Epoch 6: : 0batch [00:01, ?batch/s, Train loss=0.117, Relative Train=0, Relative Val loss=18.1]
# Epoch 7: : 0batch [00:01, ?batch/s, Train loss=0.113, Relative Train=0, Relative Val loss=12.2]
# Epoch 8: : 0batch [00:01, ?batch/s, Train loss=0.112, Relative Train=0, Relative Val loss=12.9]
# Epoch 9: : 0batch [00:01, ?batch/s, Train loss=0.114, Relative Train=0, Relative Val loss=12.9]
# Epoch 10: : 0batch [00:02, ?batch/s, Train loss=0.114, Relative Train=0, Relative Val loss=14.4]
# Epoch 11: : 0batch [00:01, ?batch/s, Train loss=0.116, Relative Train=0, Relative Val loss=18.1]
# Epoch 12: : 0batch [00:01, ?batch/s, Train loss=0.113, Relative Train=0, Relative Val loss=15]
# Epoch 13: : 0batch [00:01, ?batch/s, Train loss=0.109, Relative Train=0, Relative Val loss=11.3]
# Epoch 14: : 0batch [00:01, ?batch/s, Train loss=0.109, Relative Train=0, Relative Val loss=17]
# Epoch 15: : 0batch [00:01, ?batch/s, Train loss=0.111, Relative Train=0, Relative Val loss=13.8]
# Epoch 16: : 0batch [00:01, ?batch/s, Train loss=0.109, Relative Train=0, Relative Val loss=16.4]
# Epoch 17: : 0batch [00:02, ?batch/s, Train loss=0.107, Relative Train=0, Relative Val loss=11.7]
# Epoch 18: : 0batch [00:01, ?batch/s, Train loss=0.106, Relative Train=0, Relative Val loss=18.5]
# Epoch 19: : 0batch [00:01, ?batch/s, Train loss=0.106, Relative Train=0, Relative Val loss=11.7]
# Epoch 20: : 0batch [00:01, ?batch/s, Train loss=0.109, Relative Train=0, Relative Val loss=16.2]
# Epoch 21: : 0batch [00:01, ?batch/s, Train loss=0.107, Relative Train=0, Relative Val loss=17.7]
# Epoch 22: : 0batch [00:01, ?batch/s, Train loss=0.103, Relative Train=0, Relative Val loss=14.3]
# Epoch 23: : 0batch [00:01, ?batch/s, Train loss=0.102, Relative Train=0, Relative Val loss=10.9]
# Epoch 24: : 0batch [00:01, ?batch/s, Train loss=0.105, Relative Train=0, Relative Val loss=33.9]
# Epoch 25: : 0batch [00:02, ?batch/s, Train loss=0.108, Relative Train=0, Relative Val loss=23.8]
# Epoch 26: : 0batch [00:01, ?batch/s, Train loss=0.102, Relative Train=0, Relative Val loss=16.2]
# Epoch 27: : 0batch [00:01, ?batch/s, Train loss=0.106, Relative Train=0, Relative Val loss=15.2]
# Epoch 28: : 0batch [00:01, ?batch/s, Train loss=0.103, Relative Train=0, Relative Val loss=13.7]
# Epoch 29: : 0batch [00:01, ?batch/s, Train loss=0.0991, Relative Train=0, Relative Val loss=30.5]
# Epoch 30: : 0batch [00:01, ?batch/s, Train loss=0.0982, Relative Train=0, Relative Val loss=11.8]
# Epoch 31: : 0batch [00:01, ?batch/s, Train loss=0.102, Relative Train=0, Relative Val loss=14]
# Epoch 32: : 0batch [00:02, ?batch/s, Train loss=0.102, Relative Train=0, Relative Val loss=14.9]
# Epoch 33: : 0batch [00:01, ?batch/s, Train loss=0.1, Relative Train=0, Relative Val loss=13.4]
# Epoch 34: : 0batch [00:01, ?batch/s, Train loss=0.101, Relative Train=0, Relative Val loss=20.1]
# Epoch 35: : 0batch [00:01, ?batch/s, Train loss=0.0983, Relative Train=0, Relative Val loss=14.4]
# Epoch 36: : 0batch [00:01, ?batch/s, Train loss=0.0997, Relative Train=0, Relative Val loss=13.6]
# Epoch 37: : 0batch [00:01, ?batch/s, Train loss=0.098, Relative Train=0, Relative Val loss=12.3]
# Epoch 38: : 0batch [00:01, ?batch/s, Train loss=0.0971, Relative Train=0, Relative Val loss=12.5]
# Epoch 39: : 0batch [00:02, ?batch/s, Train loss=0.0995, Relative Train=0, Relative Val loss=11.5]
# Epoch 40: : 0batch [00:01, ?batch/s, Train loss=0.0958, Relative Train=0, Relative Val loss=10.6]
# Epoch 41: : 0batch [00:01, ?batch/s, Train loss=0.0952, Relative Train=0, Relative Val loss=20.8]
# Epoch 42: : 0batch [00:01, ?batch/s, Train loss=0.0947, Relative Train=0, Relative Val loss=10.1]
# Epoch 43: : 0batch [00:01, ?batch/s, Train loss=0.0968, Relative Train=0, Relative Val loss=19.8]
# Epoch 44: : 0batch [00:01, ?batch/s, Train loss=0.0993, Relative Train=0, Relative Val loss=13.2]
# Epoch 45: : 0batch [00:01, ?batch/s, Train loss=0.097, Relative Train=0, Relative Val loss=11.1]
# Epoch 46: : 0batch [00:02, ?batch/s, Train loss=0.096, Relative Train=0, Relative Val loss=13.7]
# Epoch 47: : 0batch [00:01, ?batch/s, Train loss=0.0952, Relative Train=0, Relative Val loss=18.5]
# Epoch 48: : 0batch [00:01, ?batch/s, Train loss=0.0948, Relative Train=0, Relative Val loss=10.6]
# Epoch 49: : 0batch [00:01, ?batch/s, Train loss=0.0959, Relative Train=0, Relative Val loss=14]
# Epoch 50: : 0batch [00:01, ?batch/s, Train loss=0.0918, Relative Train=0, Relative Val loss=15.6]
# Epoch 51: : 0batch [00:01, ?batch/s, Train loss=0.0898, Relative Train=0, Relative Val loss=17.7]
# Epoch 52: : 0batch [00:01, ?batch/s, Train loss=0.09, Relative Train=0, Relative Val loss=16.4]
# Epoch 53: : 0batch [00:01, ?batch/s, Train loss=0.0946, Relative Train=0, Relative Val loss=20.8]
# Epoch 54: : 0batch [00:02, ?batch/s, Train loss=0.0905, Relative Train=0, Relative Val loss=33.3]
# Epoch 55: : 0batch [00:01, ?batch/s, Train loss=0.0893, Relative Train=0, Relative Val loss=10.2]
# Epoch 56: : 0batch [00:01, ?batch/s, Train loss=0.0889, Relative Train=0, Relative Val loss=14.3]
# Epoch 57: : 0batch [00:01, ?batch/s, Train loss=0.087, Relative Train=0, Relative Val loss=9.53]
# Epoch 58: : 0batch [00:01, ?batch/s, Train loss=0.0871, Relative Train=0, Relative Val loss=15.2]
# Epoch 59: : 0batch [00:01, ?batch/s, Train loss=0.0826, Relative Train=0, Relative Val loss=13]
# Epoch 60: : 0batch [00:01, ?batch/s, Train loss=0.0808, Relative Train=0, Relative Val loss=14.1]
# Epoch 61: : 0batch [00:02, ?batch/s, Train loss=0.085, Relative Train=0, Relative Val loss=10.5]
# Epoch 62: : 0batch [00:01, ?batch/s, Train loss=0.0803, Relative Train=0, Relative Val loss=11.3]
# Epoch 63: : 0batch [00:01, ?batch/s, Train loss=0.0791, Relative Train=0, Relative Val loss=12.1]
# Epoch 64: : 0batch [00:01, ?batch/s, Train loss=0.0783, Relative Train=0, Relative Val loss=11]
# Epoch 65: : 0batch [00:01, ?batch/s, Train loss=0.0772, Relative Train=0, Relative Val loss=12.6]
# Epoch 66: : 0batch [00:01, ?batch/s, Train loss=0.0763, Relative Train=0, Relative Val loss=14.8]
# Epoch 67: : 0batch [00:01, ?batch/s, Train loss=0.0723, Relative Train=0, Relative Val loss=12.2]
# Epoch 68: : 0batch [00:02, ?batch/s, Train loss=0.0748, Relative Train=0, Relative Val loss=11.9]
# Epoch 69: : 0batch [00:01, ?batch/s, Train loss=0.0747, Relative Train=0, Relative Val loss=13.2]
# Epoch 70: : 0batch [00:01, ?batch/s, Train loss=0.0703, Relative Train=0, Relative Val loss=12.2]
# Epoch 71: : 0batch [00:01, ?batch/s, Train loss=0.0696, Relative Train=0, Relative Val loss=11.2]
# Epoch 72: : 0batch [00:01, ?batch/s, Train loss=0.0692, Relative Train=0, Relative Val loss=15.8]
# Epoch 73: : 0batch [00:01, ?batch/s, Train loss=0.0679, Relative Train=0, Relative Val loss=13.9]
# Epoch 74: : 0batch [00:01, ?batch/s, Train loss=0.07, Relative Train=0, Relative Val loss=11.1]
# Epoch 75: : 0batch [00:02, ?batch/s, Train loss=0.0676, Relative Train=0, Relative Val loss=9.07]
# Epoch 76: : 0batch [00:02, ?batch/s, Train loss=0.0713, Relative Train=0, Relative Val loss=8.28]
# Epoch 77: : 0batch [00:01, ?batch/s, Train loss=0.0654, Relative Train=0, Relative Val loss=7.77]
# Epoch 78: : 0batch [00:01, ?batch/s, Train loss=0.0626, Relative Train=0, Relative Val loss=8.32]
# Epoch 79: : 0batch [00:01, ?batch/s, Train loss=0.0642, Relative Train=0, Relative Val loss=10.1]
# Epoch 80: : 0batch [00:01, ?batch/s, Train loss=0.0633, Relative Train=0, Relative Val loss=12.4]
# Epoch 81: : 0batch [00:01, ?batch/s, Train loss=0.06, Relative Train=0, Relative Val loss=7.33]
# Epoch 82: : 0batch [00:02, ?batch/s, Train loss=0.0579, Relative Train=0, Relative Val loss=9.67]
# Epoch 83: : 0batch [00:02, ?batch/s, Train loss=0.0605, Relative Train=0, Relative Val loss=7.15]
# Epoch 84: : 0batch [00:01, ?batch/s, Train loss=0.0568, Relative Train=0, Relative Val loss=7.3]
# Epoch 85: : 0batch [00:01, ?batch/s, Train loss=0.064, Relative Train=0, Relative Val loss=8.57]
# Epoch 86: : 0batch [00:01, ?batch/s, Train loss=0.0613, Relative Train=0, Relative Val loss=7.16]
# Epoch 87: : 0batch [00:01, ?batch/s, Train loss=0.0592, Relative Train=0, Relative Val loss=9.42]
# Epoch 88: : 0batch [00:01, ?batch/s, Train loss=0.0566, Relative Train=0, Relative Val loss=8.09]
# Epoch 89: : 0batch [00:01, ?batch/s, Train loss=0.054, Relative Train=0, Relative Val loss=8.01]
# Epoch 90: : 0batch [00:02, ?batch/s, Train loss=0.0554, Relative Train=0, Relative Val loss=7.9]
# Epoch 91: : 0batch [00:01, ?batch/s, Train loss=0.0557, Relative Train=0, Relative Val loss=10.1]
# Epoch 92: : 0batch [00:01, ?batch/s, Train loss=0.0531, Relative Train=0, Relative Val loss=6.87]
# Epoch 93: : 0batch [00:01, ?batch/s, Train loss=0.0529, Relative Train=0, Relative Val loss=8.1]
# Epoch 94: : 0batch [00:01, ?batch/s, Train loss=0.053, Relative Train=0, Relative Val loss=8.24]
# Epoch 95: : 0batch [00:01, ?batch/s, Train loss=0.0555, Relative Train=0, Relative Val loss=8.66]
# Epoch 96: : 0batch [00:01, ?batch/s, Train loss=0.0512, Relative Train=0, Relative Val loss=7.27]
# Epoch 97: : 0batch [00:02, ?batch/s, Train loss=0.0515, Relative Train=0, Relative Val loss=6.55]
# Epoch 98: : 0batch [00:01, ?batch/s, Train loss=0.0486, Relative Train=0, Relative Val loss=7.06]
# Epoch 99: : 0batch [00:01, ?batch/s, Train loss=0.051, Relative Train=0, Relative Val loss=7.77]
# Epoch 100: : 0batch [00:01, ?batch/s, Train loss=0.0494, Relative Train=0, Relative Val loss=5.9]
# Epoch 101: : 0batch [00:01, ?batch/s, Train loss=0.0522, Relative Train=0, Relative Val loss=8.37]
# Epoch 102: : 0batch [00:01, ?batch/s, Train loss=0.0531, Relative Train=0, Relative Val loss=6.01]
# Epoch 103: : 0batch [00:01, ?batch/s, Train loss=0.0494, Relative Train=0, Relative Val loss=7.07]
# Epoch 104: : 0batch [00:01, ?batch/s, Train loss=0.0491, Relative Train=0, Relative Val loss=7.74]
# Epoch 105: : 0batch [00:02, ?batch/s, Train loss=0.0477, Relative Train=0, Relative Val loss=6.24]
# Epoch 106: : 0batch [00:01, ?batch/s, Train loss=0.0484, Relative Train=0, Relative Val loss=6.34]
# Epoch 107: : 0batch [00:01, ?batch/s, Train loss=0.0503, Relative Train=0, Relative Val loss=6.99]
# Epoch 108: : 0batch [00:01, ?batch/s, Train loss=0.0469, Relative Train=0, Relative Val loss=6.95]
# Epoch 109: : 0batch [00:01, ?batch/s, Train loss=0.046, Relative Train=0, Relative Val loss=6.12]
# Epoch 110: : 0batch [00:01, ?batch/s, Train loss=0.0435, Relative Train=0, Relative Val loss=9.63]
# Epoch 111: : 0batch [00:01, ?batch/s, Train loss=0.0462, Relative Train=0, Relative Val loss=5.93]
# Epoch 112: : 0batch [00:02, ?batch/s, Train loss=0.0485, Relative Train=0, Relative Val loss=6.37]
# Epoch 113: : 0batch [00:01, ?batch/s, Train loss=0.0464, Relative Train=0, Relative Val loss=7.17]
# Epoch 114: : 0batch [00:01, ?batch/s, Train loss=0.0462, Relative Train=0, Relative Val loss=8.01]
# Epoch 115: : 0batch [00:01, ?batch/s, Train loss=0.046, Relative Train=0, Relative Val loss=5.82]
# Epoch 116: : 0batch [00:01, ?batch/s, Train loss=0.0451, Relative Train=0, Relative Val loss=6.34]
# Epoch 117: : 0batch [00:01, ?batch/s, Train loss=0.0456, Relative Train=0, Relative Val loss=6.47]
# Epoch 118: : 0batch [00:01, ?batch/s, Train loss=0.0448, Relative Train=0, Relative Val loss=6.58]
# Epoch 119: : 0batch [00:02, ?batch/s, Train loss=0.0439, Relative Train=0, Relative Val loss=5.9]
# Epoch 120: : 0batch [00:02, ?batch/s, Train loss=0.0467, Relative Train=0, Relative Val loss=5.69]
# Epoch 121: : 0batch [00:01, ?batch/s, Train loss=0.041, Relative Train=0, Relative Val loss=5.65]
# Epoch 122: : 0batch [00:01, ?batch/s, Train loss=0.0468, Relative Train=0, Relative Val loss=6.39]
# Epoch 123: : 0batch [00:01, ?batch/s, Train loss=0.0435, Relative Train=0, Relative Val loss=6.94]
# Epoch 124: : 0batch [00:01, ?batch/s, Train loss=0.0399, Relative Train=0, Relative Val loss=6.87]
# Epoch 125: : 0batch [00:01, ?batch/s, Train loss=0.0384, Relative Train=0, Relative Val loss=6.94]
# Epoch 126: : 0batch [00:02, ?batch/s, Train loss=0.0375, Relative Train=0, Relative Val loss=6.44]
# Epoch 127: : 0batch [00:01, ?batch/s, Train loss=0.0425, Relative Train=0, Relative Val loss=9.05]
# Epoch 128: : 0batch [00:01, ?batch/s, Train loss=0.0406, Relative Train=0, Relative Val loss=6.19]
# Epoch 129: : 0batch [00:01, ?batch/s, Train loss=0.0411, Relative Train=0, Relative Val loss=5.58]
# Epoch 130: : 0batch [00:01, ?batch/s, Train loss=0.0411, Relative Train=0, Relative Val loss=6.53]
# Epoch 131: : 0batch [00:01, ?batch/s, Train loss=0.0403, Relative Train=0, Relative Val loss=5.95]
# Epoch 132: : 0batch [00:01, ?batch/s, Train loss=0.0393, Relative Train=0, Relative Val loss=6.07]
# Epoch 133: : 0batch [00:01, ?batch/s, Train loss=0.0367, Relative Train=0, Relative Val loss=6.1]
# Epoch 134: : 0batch [00:02, ?batch/s, Train loss=0.0405, Relative Train=0, Relative Val loss=6.68]
# Epoch 135: : 0batch [00:01, ?batch/s, Train loss=0.0441, Relative Train=0, Relative Val loss=6.36]
# Epoch 136: : 0batch [00:01, ?batch/s, Train loss=0.0389, Relative Train=0, Relative Val loss=6.1]
# Epoch 137: : 0batch [00:01, ?batch/s, Train loss=0.0396, Relative Train=0, Relative Val loss=7.49]
# Epoch 138: : 0batch [00:01, ?batch/s, Train loss=0.0381, Relative Train=0, Relative Val loss=5.67]
# Epoch 139: : 0batch [00:01, ?batch/s, Train loss=0.0358, Relative Train=0, Relative Val loss=5.19]
# Epoch 140: : 0batch [00:01, ?batch/s, Train loss=0.0366, Relative Train=0, Relative Val loss=5.78]
# Epoch 141: : 0batch [00:02, ?batch/s, Train loss=0.0384, Relative Train=0, Relative Val loss=5.39]
# Epoch 142: : 0batch [00:01, ?batch/s, Train loss=0.0352, Relative Train=0, Relative Val loss=5.48]
# Epoch 143: : 0batch [00:01, ?batch/s, Train loss=0.0353, Relative Train=0, Relative Val loss=6.65]
# Epoch 144: : 0batch [00:01, ?batch/s, Train loss=0.037, Relative Train=0, Relative Val loss=6.02]
# Epoch 145: : 0batch [00:01, ?batch/s, Train loss=0.0363, Relative Train=0, Relative Val loss=6.03]
# Epoch 146: : 0batch [00:01, ?batch/s, Train loss=0.0406, Relative Train=0, Relative Val loss=5.81]
# Epoch 147: : 0batch [00:01, ?batch/s, Train loss=0.0358, Relative Train=0, Relative Val loss=5.78]
# Epoch 148: : 0batch [00:02, ?batch/s, Train loss=0.035, Relative Train=0, Relative Val loss=5.03]
# Epoch 149: : 0batch [00:01, ?batch/s, Train loss=0.0356, Relative Train=0, Relative Val loss=7.48]
# Epoch 150: : 0batch [00:01, ?batch/s, Train loss=0.0338, Relative Train=0, Relative Val loss=7.58]
# Epoch 151: : 0batch [00:01, ?batch/s, Train loss=0.0334, Relative Train=0, Relative Val loss=5.3]
# Epoch 152: : 0batch [00:01, ?batch/s, Train loss=0.0335, Relative Train=0, Relative Val loss=6.24]
# Epoch 153: : 0batch [00:01, ?batch/s, Train loss=0.0369, Relative Train=0, Relative Val loss=5.47]
# Epoch 154: : 0batch [00:01, ?batch/s, Train loss=0.0376, Relative Train=0, Relative Val loss=5.1]
# Epoch 155: : 0batch [00:02, ?batch/s, Train loss=0.0353, Relative Train=0, Relative Val loss=5.99]
# Epoch 156: : 0batch [00:02, ?batch/s, Train loss=0.0363, Relative Train=0, Relative Val loss=5.39]
# Epoch 157: : 0batch [00:01, ?batch/s, Train loss=0.0355, Relative Train=0, Relative Val loss=5.78]
# Epoch 158: : 0batch [00:01, ?batch/s, Train loss=0.0332, Relative Train=0, Relative Val loss=5.49]
# Epoch 159: : 0batch [00:01, ?batch/s, Train loss=0.0328, Relative Train=0, Relative Val loss=5.34]
# Epoch 160: : 0batch [00:01, ?batch/s, Train loss=0.0321, Relative Train=0, Relative Val loss=5.61]
# Epoch 161: : 0batch [00:01, ?batch/s, Train loss=0.0364, Relative Train=0, Relative Val loss=5.42]
# Epoch 162: : 0batch [00:02, ?batch/s, Train loss=0.0331, Relative Train=0, Relative Val loss=4.88]
# Epoch 163: : 0batch [00:02, ?batch/s, Train loss=0.0337, Relative Train=0, Relative Val loss=5.39]
# Epoch 164: : 0batch [00:01, ?batch/s, Train loss=0.0312, Relative Train=0, Relative Val loss=6.28]
# Epoch 165: : 0batch [00:01, ?batch/s, Train loss=0.029, Relative Train=0, Relative Val loss=5.75]
# Epoch 166: : 0batch [00:01, ?batch/s, Train loss=0.0307, Relative Train=0, Relative Val loss=6.08]
# Epoch 167: : 0batch [00:01, ?batch/s, Train loss=0.0319, Relative Train=0, Relative Val loss=5.79]
# Epoch 168: : 0batch [00:01, ?batch/s, Train loss=0.0304, Relative Train=0, Relative Val loss=6.33]
# Epoch 169: : 0batch [00:01, ?batch/s, Train loss=0.0291, Relative Train=0, Relative Val loss=4.94]
# Epoch 170: : 0batch [00:02, ?batch/s, Train loss=0.0323, Relative Train=0, Relative Val loss=5.76]
# Epoch 171: : 0batch [00:01, ?batch/s, Train loss=0.0287, Relative Train=0, Relative Val loss=6.23]
# Epoch 172: : 0batch [00:01, ?batch/s, Train loss=0.0289, Relative Train=0, Relative Val loss=5.6]
# Epoch 173: : 0batch [00:01, ?batch/s, Train loss=0.0321, Relative Train=0, Relative Val loss=5.6]
# Epoch 174: : 0batch [00:01, ?batch/s, Train loss=0.0322, Relative Train=0, Relative Val loss=5.02]
# Epoch 175: : 0batch [00:01, ?batch/s, Train loss=0.029, Relative Train=0, Relative Val loss=4.73]
# Epoch 176: : 0batch [00:01, ?batch/s, Train loss=0.0286, Relative Train=0, Relative Val loss=7.41]
# Epoch 177: : 0batch [00:02, ?batch/s, Train loss=0.028, Relative Train=0, Relative Val loss=6.72]
# Epoch 178: : 0batch [00:01, ?batch/s, Train loss=0.0322, Relative Train=0, Relative Val loss=5.44]
# Epoch 179: : 0batch [00:01, ?batch/s, Train loss=0.0308, Relative Train=0, Relative Val loss=6.63]
# Epoch 180: : 0batch [00:01, ?batch/s, Train loss=0.0283, Relative Train=0, Relative Val loss=4.78]
# Epoch 181: : 0batch [00:01, ?batch/s, Train loss=0.0293, Relative Train=0, Relative Val loss=5.84]
# Epoch 182: : 0batch [00:01, ?batch/s, Train loss=0.0289, Relative Train=0, Relative Val loss=5.64]
# Epoch 183: : 0batch [00:01, ?batch/s, Train loss=0.0311, Relative Train=0, Relative Val loss=5.02]
# Epoch 184: : 0batch [00:01, ?batch/s, Train loss=0.0314, Relative Train=0, Relative Val loss=5.76]
# Epoch 185: : 0batch [00:02, ?batch/s, Train loss=0.0305, Relative Train=0, Relative Val loss=4.82]
# Epoch 186: : 0batch [00:01, ?batch/s, Train loss=0.0294, Relative Train=0, Relative Val loss=5.36]
# Epoch 187: : 0batch [00:01, ?batch/s, Train loss=0.0353, Relative Train=0, Relative Val loss=6.25]
# Epoch 188: : 0batch [00:01, ?batch/s, Train loss=0.03, Relative Train=0, Relative Val loss=4.65]
# Epoch 189: : 0batch [00:01, ?batch/s, Train loss=0.0301, Relative Train=0, Relative Val loss=5.08]
# Epoch 190: : 0batch [00:01, ?batch/s, Train loss=0.0308, Relative Train=0, Relative Val loss=4.98]
# Epoch 191: : 0batch [00:01, ?batch/s, Train loss=0.0287, Relative Train=0, Relative Val loss=5.4]
# Epoch 192: : 0batch [00:02, ?batch/s, Train loss=0.0292, Relative Train=0, Relative Val loss=4.93]
# Epoch 193: : 0batch [00:01, ?batch/s, Train loss=0.03, Relative Train=0, Relative Val loss=5.03]
# Epoch 194: : 0batch [00:01, ?batch/s, Train loss=0.0311, Relative Train=0, Relative Val loss=5.7]
# Epoch 195: : 0batch [00:01, ?batch/s, Train loss=0.0291, Relative Train=0, Relative Val loss=5.29]
# Epoch 196: : 0batch [00:01, ?batch/s, Train loss=0.0266, Relative Train=0, Relative Val loss=4.71]
# Epoch 197: : 0batch [00:01, ?batch/s, Train loss=0.0287, Relative Train=0, Relative Val loss=5.14]
# Epoch 198: : 0batch [00:01, ?batch/s, Train loss=0.0275, Relative Train=0, Relative Val loss=5.2]
# Epoch 199: : 0batch [00:02, ?batch/s, Train loss=0.0244, Relative Train=0, Relative Val loss=4.96]
# Epoch 200: : 0batch [00:01, ?batch/s, Train loss=0.0249, Relative Train=0, Relative Val loss=5.64]
# Epoch 201: : 0batch [00:01, ?batch/s, Train loss=0.0282, Relative Train=0, Relative Val loss=4.97]
# Epoch 202: : 0batch [00:01, ?batch/s, Train loss=0.0268, Relative Train=0, Relative Val loss=5.13]
# Epoch 203: : 0batch [00:01, ?batch/s, Train loss=0.0272, Relative Train=0, Relative Val loss=5.14]
# Epoch 204: : 0batch [00:01, ?batch/s, Train loss=0.0261, Relative Train=0, Relative Val loss=6.63]
# Epoch 205: : 0batch [00:01, ?batch/s, Train loss=0.0309, Relative Train=0, Relative Val loss=7.74]
# Epoch 206: : 0batch [00:01, ?batch/s, Train loss=0.0289, Relative Train=0, Relative Val loss=5.29]
# Epoch 207: : 0batch [00:02, ?batch/s, Train loss=0.0261, Relative Train=0, Relative Val loss=8.01]
# Epoch 208: : 0batch [00:01, ?batch/s, Train loss=0.0261, Relative Train=0, Relative Val loss=4.45]
# Epoch 209: : 0batch [00:01, ?batch/s, Train loss=0.0256, Relative Train=0, Relative Val loss=4.76]
# Epoch 210: : 0batch [00:01, ?batch/s, Train loss=0.0267, Relative Train=0, Relative Val loss=6.21]
# Epoch 211: : 0batch [00:01, ?batch/s, Train loss=0.0243, Relative Train=0, Relative Val loss=5.38]
# Epoch 212: : 0batch [00:01, ?batch/s, Train loss=0.0264, Relative Train=0, Relative Val loss=4.84]
# Epoch 213: : 0batch [00:01, ?batch/s, Train loss=0.0259, Relative Train=0, Relative Val loss=4.92]
# Epoch 214: : 0batch [00:02, ?batch/s, Train loss=0.0248, Relative Train=0, Relative Val loss=4.87]
# Epoch 215: : 0batch [00:01, ?batch/s, Train loss=0.0256, Relative Train=0, Relative Val loss=5.09]
# Epoch 216: : 0batch [00:01, ?batch/s, Train loss=0.0261, Relative Train=0, Relative Val loss=5.35]
# Epoch 217: : 0batch [00:01, ?batch/s, Train loss=0.024, Relative Train=0, Relative Val loss=5.3]
# Epoch 218: : 0batch [00:01, ?batch/s, Train loss=0.0238, Relative Train=0, Relative Val loss=4.71]
# Epoch 219: : 0batch [00:01, ?batch/s, Train loss=0.0244, Relative Train=0, Relative Val loss=4.8]
# Epoch 220: : 0batch [00:01, ?batch/s, Train loss=0.0253, Relative Train=0, Relative Val loss=5.79]
# Epoch 221: : 0batch [00:02, ?batch/s, Train loss=0.0243, Relative Train=0, Relative Val loss=5.69]
# Epoch 222: : 0batch [00:01, ?batch/s, Train loss=0.0235, Relative Train=0, Relative Val loss=4.81]
# Epoch 223: : 0batch [00:01, ?batch/s, Train loss=0.0253, Relative Train=0, Relative Val loss=4.98]
# Epoch 224: : 0batch [00:01, ?batch/s, Train loss=0.0251, Relative Train=0, Relative Val loss=4.93]
# Epoch 225: : 0batch [00:01, ?batch/s, Train loss=0.0234, Relative Train=0, Relative Val loss=6.22]
# Epoch 226: : 0batch [00:01, ?batch/s, Train loss=0.0256, Relative Train=0, Relative Val loss=4.65]
# Epoch 227: : 0batch [00:01, ?batch/s, Train loss=0.0254, Relative Train=0, Relative Val loss=4.89]
# Epoch 228: : 0batch [00:01, ?batch/s, Train loss=0.0237, Relative Train=0, Relative Val loss=4.6]
# Epoch 229: : 0batch [00:02, ?batch/s, Train loss=0.0234, Relative Train=0, Relative Val loss=4.79]
# Epoch 230: : 0batch [00:01, ?batch/s, Train loss=0.023, Relative Train=0, Relative Val loss=4.9]
# Epoch 231: : 0batch [00:01, ?batch/s, Train loss=0.0233, Relative Train=0, Relative Val loss=4.67]
# Epoch 232: : 0batch [00:01, ?batch/s, Train loss=0.023, Relative Train=0, Relative Val loss=5.56]
# Epoch 233: : 0batch [00:01, ?batch/s, Train loss=0.025, Relative Train=0, Relative Val loss=4.9]
# Epoch 234: : 0batch [00:01, ?batch/s, Train loss=0.0261, Relative Train=0, Relative Val loss=6.03]
# Epoch 235: : 0batch [00:01, ?batch/s, Train loss=0.0256, Relative Train=0, Relative Val loss=4.81]
# Epoch 236: : 0batch [00:02, ?batch/s, Train loss=0.0269, Relative Train=0, Relative Val loss=5.16]
# Epoch 237: : 0batch [00:01, ?batch/s, Train loss=0.0246, Relative Train=0, Relative Val loss=4.8]
# Epoch 238: : 0batch [00:01, ?batch/s, Train loss=0.0242, Relative Train=0, Relative Val loss=4.89]
# Epoch 239: : 0batch [00:01, ?batch/s, Train loss=0.0243, Relative Train=0, Relative Val loss=4.37]
# Epoch 240: : 0batch [00:01, ?batch/s, Train loss=0.0219, Relative Train=0, Relative Val loss=4.65]
# Epoch 241: : 0batch [00:01, ?batch/s, Train loss=0.0244, Relative Train=0, Relative Val loss=4.35]
# Epoch 242: : 0batch [00:01, ?batch/s, Train loss=0.0233, Relative Train=0, Relative Val loss=4.48]
# Epoch 243: : 0batch [00:02, ?batch/s, Train loss=0.0215, Relative Train=0, Relative Val loss=4.87]
# Epoch 244: : 0batch [00:01, ?batch/s, Train loss=0.0226, Relative Train=0, Relative Val loss=4.56]
# Epoch 245: : 0batch [00:01, ?batch/s, Train loss=0.0223, Relative Train=0, Relative Val loss=4.93]
# Epoch 246: : 0batch [00:01, ?batch/s, Train loss=0.0237, Relative Train=0, Relative Val loss=4.74]
# Epoch 247: : 0batch [00:01, ?batch/s, Train loss=0.0238, Relative Train=0, Relative Val loss=4.72]
# Epoch 248: : 0batch [00:01, ?batch/s, Train loss=0.0211, Relative Train=0, Relative Val loss=4.55]
# Epoch 249: : 0batch [00:01, ?batch/s, Train loss=0.0229, Relative Train=0, Relative Val loss=5.15]
# Epoch 250: : 0batch [00:01, ?batch/s, Train loss=0.0217, Relative Train=0, Relative Val loss=4.52]
# Epoch 251: : 0batch [00:02, ?batch/s, Train loss=0.0206, Relative Train=0, Relative Val loss=4.6]
# Epoch 252: : 0batch [00:01, ?batch/s, Train loss=0.0199, Relative Train=0, Relative Val loss=4.66]
# Epoch 253: : 0batch [00:01, ?batch/s, Train loss=0.02, Relative Train=0, Relative Val loss=4.74]
# Epoch 254: : 0batch [00:01, ?batch/s, Train loss=0.0238, Relative Train=0, Relative Val loss=4.79]
# Epoch 255: : 0batch [00:01, ?batch/s, Train loss=0.0237, Relative Train=0, Relative Val loss=5.41]
# Epoch 256: : 0batch [00:01, ?batch/s, Train loss=0.0216, Relative Train=0, Relative Val loss=4.37]
# Epoch 257: : 0batch [00:01, ?batch/s, Train loss=0.0213, Relative Train=0, Relative Val loss=4.6]
# Epoch 258: : 0batch [00:02, ?batch/s, Train loss=0.0219, Relative Train=0, Relative Val loss=4.46]
# Epoch 259: : 0batch [00:01, ?batch/s, Train loss=0.0212, Relative Train=0, Relative Val loss=4.69]
# Epoch 260: : 0batch [00:01, ?batch/s, Train loss=0.0199, Relative Train=0, Relative Val loss=4.71]
# Epoch 261: : 0batch [00:01, ?batch/s, Train loss=0.0192, Relative Train=0, Relative Val loss=4.61]
# Epoch 262: : 0batch [00:01, ?batch/s, Train loss=0.0216, Relative Train=0, Relative Val loss=5.05]
# Epoch 263: : 0batch [00:01, ?batch/s, Train loss=0.0201, Relative Train=0, Relative Val loss=4.71]
# Epoch 264: : 0batch [00:01, ?batch/s, Train loss=0.02, Relative Train=0, Relative Val loss=4.51]
# Epoch 265: : 0batch [00:02, ?batch/s, Train loss=0.0211, Relative Train=0, Relative Val loss=4.82]
# Epoch 266: : 0batch [00:01, ?batch/s, Train loss=0.0204, Relative Train=0, Relative Val loss=5.44]
# Epoch 267: : 0batch [00:01, ?batch/s, Train loss=0.0201, Relative Train=0, Relative Val loss=4.81]
# Epoch 268: : 0batch [00:01, ?batch/s, Train loss=0.0219, Relative Train=0, Relative Val loss=5.02]
# Epoch 269: : 0batch [00:01, ?batch/s, Train loss=0.0201, Relative Train=0, Relative Val loss=5.16]
# Epoch 270: : 0batch [00:01, ?batch/s, Train loss=0.0189, Relative Train=0, Relative Val loss=4.48]
# Epoch 271: : 0batch [00:01, ?batch/s, Train loss=0.022, Relative Train=0, Relative Val loss=4.51]
# Epoch 272: : 0batch [00:02, ?batch/s, Train loss=0.0207, Relative Train=0, Relative Val loss=4.56]
# Epoch 273: : 0batch [00:01, ?batch/s, Train loss=0.0201, Relative Train=0, Relative Val loss=4.64]
# Epoch 274: : 0batch [00:01, ?batch/s, Train loss=0.0192, Relative Train=0, Relative Val loss=4.38]
# Epoch 275: : 0batch [00:01, ?batch/s, Train loss=0.02, Relative Train=0, Relative Val loss=4.61]
# Epoch 276: : 0batch [00:01, ?batch/s, Train loss=0.0205, Relative Train=0, Relative Val loss=4.6]
# Epoch 277: : 0batch [00:01, ?batch/s, Train loss=0.0205, Relative Train=0, Relative Val loss=5.19]
# Epoch 278: : 0batch [00:01, ?batch/s, Train loss=0.0204, Relative Train=0, Relative Val loss=4.96]
# Epoch 279: : 0batch [00:01, ?batch/s, Train loss=0.0199, Relative Train=0, Relative Val loss=4.78]
# Epoch 280: : 0batch [00:02, ?batch/s, Train loss=0.0218, Relative Train=0, Relative Val loss=4.4]
# Epoch 281: : 0batch [00:01, ?batch/s, Train loss=0.0205, Relative Train=0, Relative Val loss=4.91]
# Epoch 282: : 0batch [00:01, ?batch/s, Train loss=0.0203, Relative Train=0, Relative Val loss=4.43]
# Epoch 283: : 0batch [00:01, ?batch/s, Train loss=0.0189, Relative Train=0, Relative Val loss=4.47]
# Epoch 284: : 0batch [00:01, ?batch/s, Train loss=0.0197, Relative Train=0, Relative Val loss=4.5]
# Epoch 285: : 0batch [00:01, ?batch/s, Train loss=0.0198, Relative Train=0, Relative Val loss=4.49]
# Epoch 286: : 0batch [00:01, ?batch/s, Train loss=0.0185, Relative Train=0, Relative Val loss=4.77]
# Epoch 287: : 0batch [00:02, ?batch/s, Train loss=0.0196, Relative Train=0, Relative Val loss=4.49]
# Epoch 288: : 0batch [00:01, ?batch/s, Train loss=0.0186, Relative Train=0, Relative Val loss=4.42]
# Epoch 289: : 0batch [00:01, ?batch/s, Train loss=0.0204, Relative Train=0, Relative Val loss=4.56]
# Epoch 290: : 0batch [00:01, ?batch/s, Train loss=0.0208, Relative Train=0, Relative Val loss=4.44]
# Epoch 291: : 0batch [00:01, ?batch/s, Train loss=0.0194, Relative Train=0, Relative Val loss=5.15]
# Epoch 292: : 0batch [00:01, ?batch/s, Train loss=0.0198, Relative Train=0, Relative Val loss=4.48]
# Epoch 293: : 0batch [00:01, ?batch/s, Train loss=0.0198, Relative Train=0, Relative Val loss=4.62]
# Epoch 294: : 0batch [00:02, ?batch/s, Train loss=0.0194, Relative Train=0, Relative Val loss=4.56]
# Epoch 295: : 0batch [00:01, ?batch/s, Train loss=0.0192, Relative Train=0, Relative Val loss=4.63]
# Epoch 296: : 0batch [00:01, ?batch/s, Train loss=0.0186, Relative Train=0, Relative Val loss=4.48]
# Epoch 297: : 0batch [00:01, ?batch/s, Train loss=0.0189, Relative Train=0, Relative Val loss=4.63]
# Epoch 298: : 0batch [00:01, ?batch/s, Train loss=0.019, Relative Train=0, Relative Val loss=4.68]
# Epoch 299: : 0batch [00:01, ?batch/s, Train loss=0.0202, Relative Train=0, Relative Val loss=4.5]
# Epoch 300: : 0batch [00:01, ?batch/s, Train loss=0.0178, Relative Train=0, Relative Val loss=4.73]
# Epoch 301: : 0batch [00:02, ?batch/s, Train loss=0.0182, Relative Train=0, Relative Val loss=5.11]
# Epoch 302: : 0batch [00:02, ?batch/s, Train loss=0.0195, Relative Train=0, Relative Val loss=4.43]
# Epoch 303: : 0batch [00:01, ?batch/s, Train loss=0.0194, Relative Train=0, Relative Val loss=4.56]
# Epoch 304: : 0batch [00:01, ?batch/s, Train loss=0.0184, Relative Train=0, Relative Val loss=4.46]
# Epoch 305: : 0batch [00:01, ?batch/s, Train loss=0.0191, Relative Train=0, Relative Val loss=4.74]
# Epoch 306: : 0batch [00:01, ?batch/s, Train loss=0.019, Relative Train=0, Relative Val loss=4.58]
# Epoch 307: : 0batch [00:02, ?batch/s, Train loss=0.019, Relative Train=0, Relative Val loss=4.35]
# Epoch 308: : 0batch [00:02, ?batch/s, Train loss=0.0177, Relative Train=0, Relative Val loss=4.39]
# Epoch 309: : 0batch [00:02, ?batch/s, Train loss=0.0176, Relative Train=0, Relative Val loss=4.68]
# Epoch 310: : 0batch [00:01, ?batch/s, Train loss=0.0189, Relative Train=0, Relative Val loss=5.47]
# Epoch 311: : 0batch [00:01, ?batch/s, Train loss=0.0175, Relative Train=0, Relative Val loss=5.26]
# Epoch 312: : 0batch [00:01, ?batch/s, Train loss=0.0175, Relative Train=0, Relative Val loss=4.53]
# Epoch 313: : 0batch [00:01, ?batch/s, Train loss=0.0173, Relative Train=0, Relative Val loss=4.64]
# Epoch 314: : 0batch [00:01, ?batch/s, Train loss=0.0177, Relative Train=0, Relative Val loss=4.34]
# Epoch 315: : 0batch [00:01, ?batch/s, Train loss=0.0168, Relative Train=0, Relative Val loss=4.39]
# Epoch 316: : 0batch [00:02, ?batch/s, Train loss=0.0188, Relative Train=0, Relative Val loss=4.66]
# Epoch 317: : 0batch [00:01, ?batch/s, Train loss=0.0201, Relative Train=0, Relative Val loss=5.72]
# Epoch 318: : 0batch [00:01, ?batch/s, Train loss=0.0174, Relative Train=0, Relative Val loss=5.02]
# Epoch 319: : 0batch [00:01, ?batch/s, Train loss=0.0171, Relative Train=0, Relative Val loss=4.77]
# Epoch 320: : 0batch [00:01, ?batch/s, Train loss=0.0184, Relative Train=0, Relative Val loss=4.55]
# Epoch 321: : 0batch [00:01, ?batch/s, Train loss=0.0176, Relative Train=0, Relative Val loss=4.39]
# Epoch 322: : 0batch [00:01, ?batch/s, Train loss=0.0172, Relative Train=0, Relative Val loss=4.35]
# Epoch 323: : 0batch [00:02, ?batch/s, Train loss=0.0173, Relative Train=0, Relative Val loss=4.61]
# Epoch 324: : 0batch [00:01, ?batch/s, Train loss=0.0179, Relative Train=0, Relative Val loss=4.34]
# Epoch 325: : 0batch [00:01, ?batch/s, Train loss=0.0165, Relative Train=0, Relative Val loss=4.48]
# Epoch 326: : 0batch [00:01, ?batch/s, Train loss=0.0179, Relative Train=0, Relative Val loss=4.39]
# Epoch 327: : 0batch [00:01, ?batch/s, Train loss=0.0175, Relative Train=0, Relative Val loss=4.27]
# Epoch 328: : 0batch [00:01, ?batch/s, Train loss=0.0181, Relative Train=0, Relative Val loss=4.55]
# Epoch 329: : 0batch [00:01, ?batch/s, Train loss=0.017, Relative Train=0, Relative Val loss=4.36]
# Epoch 330: : 0batch [00:02, ?batch/s, Train loss=0.0176, Relative Train=0, Relative Val loss=5.24]
# Epoch 331: : 0batch [00:01, ?batch/s, Train loss=0.0167, Relative Train=0, Relative Val loss=4.64]
# Epoch 332: : 0batch [00:01, ?batch/s, Train loss=0.0157, Relative Train=0, Relative Val loss=4.39]
# Epoch 333: : 0batch [00:01, ?batch/s, Train loss=0.0159, Relative Train=0, Relative Val loss=4.48]
# Epoch 334: : 0batch [00:01, ?batch/s, Train loss=0.0156, Relative Train=0, Relative Val loss=4.62]
# Epoch 335: : 0batch [00:01, ?batch/s, Train loss=0.0181, Relative Train=0, Relative Val loss=4.58]
# Epoch 336: : 0batch [00:01, ?batch/s, Train loss=0.0175, Relative Train=0, Relative Val loss=4.45]
# Epoch 337: : 0batch [00:02, ?batch/s, Train loss=0.017, Relative Train=0, Relative Val loss=4.65]
# Epoch 338: : 0batch [00:01, ?batch/s, Train loss=0.0168, Relative Train=0, Relative Val loss=4.58]
# Epoch 339: : 0batch [00:01, ?batch/s, Train loss=0.0163, Relative Train=0, Relative Val loss=4.32]
# Epoch 340: : 0batch [00:01, ?batch/s, Train loss=0.0167, Relative Train=0, Relative Val loss=4.42]
# Epoch 341: : 0batch [00:01, ?batch/s, Train loss=0.0158, Relative Train=0, Relative Val loss=4.51]
# Epoch 342: : 0batch [00:01, ?batch/s, Train loss=0.0167, Relative Train=0, Relative Val loss=4.39]
# Epoch 343: : 0batch [00:01, ?batch/s, Train loss=0.0161, Relative Train=0, Relative Val loss=4.39]
# Epoch 344: : 0batch [00:01, ?batch/s, Train loss=0.0161, Relative Train=0, Relative Val loss=4.78]
# Epoch 345: : 0batch [00:02, ?batch/s, Train loss=0.0154, Relative Train=0, Relative Val loss=4.23]
# Epoch 346: : 0batch [00:01, ?batch/s, Train loss=0.0168, Relative Train=0, Relative Val loss=4.67]
# Epoch 347: : 0batch [00:01, ?batch/s, Train loss=0.017, Relative Train=0, Relative Val loss=4.62]
# Epoch 348: : 0batch [00:01, ?batch/s, Train loss=0.0166, Relative Train=0, Relative Val loss=4.38]
# Epoch 349: : 0batch [00:01, ?batch/s, Train loss=0.0171, Relative Train=0, Relative Val loss=4.7]
# Epoch 350: : 0batch [00:01, ?batch/s, Train loss=0.0164, Relative Train=0, Relative Val loss=4.54]
# Epoch 351: : 0batch [00:01, ?batch/s, Train loss=0.016, Relative Train=0, Relative Val loss=4.32]
# Epoch 352: : 0batch [00:02, ?batch/s, Train loss=0.0163, Relative Train=0, Relative Val loss=4.53]
# Epoch 353: : 0batch [00:01, ?batch/s, Train loss=0.0165, Relative Train=0, Relative Val loss=4.71]
# Epoch 354: : 0batch [00:01, ?batch/s, Train loss=0.0164, Relative Train=0, Relative Val loss=4.37]
# Epoch 355: : 0batch [00:01, ?batch/s, Train loss=0.0168, Relative Train=0, Relative Val loss=4.64]
# Epoch 356: : 0batch [00:01, ?batch/s, Train loss=0.0176, Relative Train=0, Relative Val loss=4.42]
# Epoch 357: : 0batch [00:01, ?batch/s, Train loss=0.0165, Relative Train=0, Relative Val loss=4.64]
# Epoch 358: : 0batch [00:01, ?batch/s, Train loss=0.0158, Relative Train=0, Relative Val loss=4.33]
# Epoch 359: : 0batch [00:02, ?batch/s, Train loss=0.0167, Relative Train=0, Relative Val loss=4.89]
# Epoch 360: : 0batch [00:01, ?batch/s, Train loss=0.0167, Relative Train=0, Relative Val loss=4.72]
# Epoch 361: : 0batch [00:01, ?batch/s, Train loss=0.0169, Relative Train=0, Relative Val loss=4.35]
# Epoch 362: : 0batch [00:01, ?batch/s, Train loss=0.0159, Relative Train=0, Relative Val loss=4.25]
# Epoch 363: : 0batch [00:01, ?batch/s, Train loss=0.0144, Relative Train=0, Relative Val loss=4.37]
# Epoch 364: : 0batch [00:01, ?batch/s, Train loss=0.0163, Relative Train=0, Relative Val loss=4.39]
# Epoch 365: : 0batch [00:01, ?batch/s, Train loss=0.0149, Relative Train=0, Relative Val loss=4.53]
# Epoch 366: : 0batch [00:02, ?batch/s, Train loss=0.0151, Relative Train=0, Relative Val loss=4.43]
# Epoch 367: : 0batch [00:01, ?batch/s, Train loss=0.0147, Relative Train=0, Relative Val loss=4.44]
# Epoch 368: : 0batch [00:01, ?batch/s, Train loss=0.0159, Relative Train=0, Relative Val loss=4.64]
# Epoch 369: : 0batch [00:01, ?batch/s, Train loss=0.0171, Relative Train=0, Relative Val loss=4.34]
# Epoch 370: : 0batch [00:01, ?batch/s, Train loss=0.0159, Relative Train=0, Relative Val loss=4.29]
# Epoch 371: : 0batch [00:01, ?batch/s, Train loss=0.0161, Relative Train=0, Relative Val loss=4.35]
# Epoch 372: : 0batch [00:01, ?batch/s, Train loss=0.0157, Relative Train=0, Relative Val loss=4.32]
# Epoch 373: : 0batch [00:01, ?batch/s, Train loss=0.0156, Relative Train=0, Relative Val loss=4.72]
# Epoch 374: : 0batch [00:02, ?batch/s, Train loss=0.0165, Relative Train=0, Relative Val loss=4.46]
# Epoch 375: : 0batch [00:01, ?batch/s, Train loss=0.0169, Relative Train=0, Relative Val loss=4.68]
# Epoch 376: : 0batch [00:01, ?batch/s, Train loss=0.0162, Relative Train=0, Relative Val loss=4.43]
# Epoch 377: : 0batch [00:01, ?batch/s, Train loss=0.0153, Relative Train=0, Relative Val loss=4.48]
# Epoch 378: : 0batch [00:01, ?batch/s, Train loss=0.0149, Relative Train=0, Relative Val loss=4.66]
# Epoch 379: : 0batch [00:01, ?batch/s, Train loss=0.0146, Relative Train=0, Relative Val loss=4.33]
# Epoch 380: : 0batch [00:01, ?batch/s, Train loss=0.0143, Relative Train=0, Relative Val loss=4.22]
# Epoch 381: : 0batch [00:02, ?batch/s, Train loss=0.0145, Relative Train=0, Relative Val loss=4.27]
# Epoch 382: : 0batch [00:01, ?batch/s, Train loss=0.0163, Relative Train=0, Relative Val loss=4.32]
# Epoch 383: : 0batch [00:01, ?batch/s, Train loss=0.0153, Relative Train=0, Relative Val loss=4.3]
# Epoch 384: : 0batch [00:01, ?batch/s, Train loss=0.0157, Relative Train=0, Relative Val loss=4.51]
# Epoch 385: : 0batch [00:01, ?batch/s, Train loss=0.0156, Relative Train=0, Relative Val loss=4.33]
# Epoch 386: : 0batch [00:01, ?batch/s, Train loss=0.016, Relative Train=0, Relative Val loss=4.8]
# Epoch 387: : 0batch [00:01, ?batch/s, Train loss=0.0151, Relative Train=0, Relative Val loss=4.61]
# Epoch 388: : 0batch [00:01, ?batch/s, Train loss=0.015, Relative Train=0, Relative Val loss=4.53]
# Epoch 389: : 0batch [00:01, ?batch/s, Train loss=0.0161, Relative Train=0, Relative Val loss=4.4]
# Epoch 390: : 0batch [00:01, ?batch/s, Train loss=0.0152, Relative Train=0, Relative Val loss=4.52]
# Epoch 391: : 0batch [00:01, ?batch/s, Train loss=0.0153, Relative Train=0, Relative Val loss=4.6]
# Epoch 392: : 0batch [00:01, ?batch/s, Train loss=0.0143, Relative Train=0, Relative Val loss=4.37]
# Epoch 393: : 0batch [00:01, ?batch/s, Train loss=0.0137, Relative Train=0, Relative Val loss=4.3]
# Epoch 394: : 0batch [00:01, ?batch/s, Train loss=0.014, Relative Train=0, Relative Val loss=4.53]
# Epoch 395: : 0batch [00:01, ?batch/s, Train loss=0.0139, Relative Train=0, Relative Val loss=4.26]
# Epoch 396: : 0batch [00:02, ?batch/s, Train loss=0.0151, Relative Train=0, Relative Val loss=4.41]
# Epoch 397: : 0batch [00:01, ?batch/s, Train loss=0.0145, Relative Train=0, Relative Val loss=4.55]
# Epoch 398: : 0batch [00:01, ?batch/s, Train loss=0.0154, Relative Train=0, Relative Val loss=4.72]
# Epoch 399: : 0batch [00:01, ?batch/s, Train loss=0.0146, Relative Train=0, Relative Val loss=4.37]
# Epoch 400: : 0batch [00:01, ?batch/s, Train loss=0.0154, Relative Train=0, Relative Val loss=4.28]
# Epoch 401: : 0batch [00:01, ?batch/s, Train loss=0.016, Relative Train=0, Relative Val loss=4.25]
# Epoch 402: : 0batch [00:01, ?batch/s, Train loss=0.0153, Relative Train=0, Relative Val loss=4.42]
# Epoch 403: : 0batch [00:02, ?batch/s, Train loss=0.0138, Relative Train=0, Relative Val loss=4.35]
# Epoch 404: : 0batch [00:01, ?batch/s, Train loss=0.0148, Relative Train=0, Relative Val loss=4.27]
# Epoch 405: : 0batch [00:01, ?batch/s, Train loss=0.0159, Relative Train=0, Relative Val loss=4.32]
# Epoch 406: : 0batch [00:01, ?batch/s, Train loss=0.0155, Relative Train=0, Relative Val loss=4.35]
# Epoch 407: : 0batch [00:01, ?batch/s, Train loss=0.0141, Relative Train=0, Relative Val loss=4.39]
# Epoch 408: : 0batch [00:01, ?batch/s, Train loss=0.0135, Relative Train=0, Relative Val loss=4.56]
# Epoch 409: : 0batch [00:01, ?batch/s, Train loss=0.0141, Relative Train=0, Relative Val loss=4.38]
# Epoch 410: : 0batch [00:02, ?batch/s, Train loss=0.0148, Relative Train=0, Relative Val loss=4.52]
# Epoch 411: : 0batch [00:01, ?batch/s, Train loss=0.0145, Relative Train=0, Relative Val loss=4.34]
# Epoch 412: : 0batch [00:01, ?batch/s, Train loss=0.0144, Relative Train=0, Relative Val loss=4.34]
# Epoch 413: : 0batch [00:01, ?batch/s, Train loss=0.0139, Relative Train=0, Relative Val loss=4.26]
# Epoch 414: : 0batch [00:01, ?batch/s, Train loss=0.0136, Relative Train=0, Relative Val loss=4.35]
# Epoch 415: : 0batch [00:01, ?batch/s, Train loss=0.0141, Relative Train=0, Relative Val loss=4.35]
# Epoch 416: : 0batch [00:01, ?batch/s, Train loss=0.014, Relative Train=0, Relative Val loss=4.24]
# Epoch 417: : 0batch [00:02, ?batch/s, Train loss=0.0135, Relative Train=0, Relative Val loss=4.72]
# Epoch 418: : 0batch [00:01, ?batch/s, Train loss=0.0142, Relative Train=0, Relative Val loss=4.31]
# Epoch 419: : 0batch [00:01, ?batch/s, Train loss=0.0146, Relative Train=0, Relative Val loss=4.37]
# Epoch 420: : 0batch [00:01, ?batch/s, Train loss=0.015, Relative Train=0, Relative Val loss=4.54]
# Epoch 421: : 0batch [00:01, ?batch/s, Train loss=0.0143, Relative Train=0, Relative Val loss=4.49]
# Epoch 422: : 0batch [00:01, ?batch/s, Train loss=0.0145, Relative Train=0, Relative Val loss=4.53]
# Epoch 423: : 0batch [00:01, ?batch/s, Train loss=0.0142, Relative Train=0, Relative Val loss=4.36]
# Epoch 424: : 0batch [00:02, ?batch/s, Train loss=0.0139, Relative Train=0, Relative Val loss=4.24]
# Epoch 425: : 0batch [00:02, ?batch/s, Train loss=0.0139, Relative Train=0, Relative Val loss=4.36]
# Epoch 426: : 0batch [00:01, ?batch/s, Train loss=0.0143, Relative Train=0, Relative Val loss=4.27]
# Epoch 427: : 0batch [00:01, ?batch/s, Train loss=0.0138, Relative Train=0, Relative Val loss=4.33]
# Epoch 428: : 0batch [00:01, ?batch/s, Train loss=0.0141, Relative Train=0, Relative Val loss=4.23]
# Epoch 429: : 0batch [00:01, ?batch/s, Train loss=0.0148, Relative Train=0, Relative Val loss=4.42]
# Epoch 430: : 0batch [00:01, ?batch/s, Train loss=0.0138, Relative Train=0, Relative Val loss=4.38]
# Epoch 431: : 0batch [00:01, ?batch/s, Train loss=0.0134, Relative Train=0, Relative Val loss=4.55]
# Epoch 432: : 0batch [00:02, ?batch/s, Train loss=0.0146, Relative Train=0, Relative Val loss=4.41]
# Epoch 433: : 0batch [00:01, ?batch/s, Train loss=0.0138, Relative Train=0, Relative Val loss=4.32]
# Epoch 434: : 0batch [00:01, ?batch/s, Train loss=0.0138, Relative Train=0, Relative Val loss=4.27]
# Epoch 435: : 0batch [00:01, ?batch/s, Train loss=0.0135, Relative Train=0, Relative Val loss=4.59]
# Epoch 436: : 0batch [00:01, ?batch/s, Train loss=0.0145, Relative Train=0, Relative Val loss=4.37]
# Epoch 437: : 0batch [00:01, ?batch/s, Train loss=0.0148, Relative Train=0, Relative Val loss=4.36]
# Epoch 438: : 0batch [00:01, ?batch/s, Train loss=0.0138, Relative Train=0, Relative Val loss=4.29]
# Epoch 439: : 0batch [00:02, ?batch/s, Train loss=0.0129, Relative Train=0, Relative Val loss=4.35]
# Epoch 440: : 0batch [00:01, ?batch/s, Train loss=0.0128, Relative Train=0, Relative Val loss=4.24]
# Epoch 441: : 0batch [00:01, ?batch/s, Train loss=0.0137, Relative Train=0, Relative Val loss=4.36]
# Epoch 442: : 0batch [00:01, ?batch/s, Train loss=0.0126, Relative Train=0, Relative Val loss=4.61]
# Epoch 443: : 0batch [00:01, ?batch/s, Train loss=0.0131, Relative Train=0, Relative Val loss=4.17]
# Epoch 444: : 0batch [00:01, ?batch/s, Train loss=0.0131, Relative Train=0, Relative Val loss=4.28]
# Epoch 445: : 0batch [00:01, ?batch/s, Train loss=0.0131, Relative Train=0, Relative Val loss=4.23]
# Epoch 446: : 0batch [00:02, ?batch/s, Train loss=0.0127, Relative Train=0, Relative Val loss=4.58]
# Epoch 447: : 0batch [00:01, ?batch/s, Train loss=0.0131, Relative Train=0, Relative Val loss=4.33]
# Epoch 448: : 0batch [00:01, ?batch/s, Train loss=0.0131, Relative Train=0, Relative Val loss=4.2]
# Epoch 449: : 0batch [00:01, ?batch/s, Train loss=0.0145, Relative Train=0, Relative Val loss=4.45]
# Epoch 450: : 0batch [00:01, ?batch/s, Train loss=0.0134, Relative Train=0, Relative Val loss=4.43]
# Epoch 451: : 0batch [00:01, ?batch/s, Train loss=0.014, Relative Train=0, Relative Val loss=4.25]
# Epoch 452: : 0batch [00:01, ?batch/s, Train loss=0.0136, Relative Train=0, Relative Val loss=4.4]
# Epoch 453: : 0batch [00:02, ?batch/s, Train loss=0.0131, Relative Train=0, Relative Val loss=4.4]
# Epoch 454: : 0batch [00:01, ?batch/s, Train loss=0.0145, Relative Train=0, Relative Val loss=4.65]
# Epoch 455: : 0batch [00:01, ?batch/s, Train loss=0.0136, Relative Train=0, Relative Val loss=4.29]
# Epoch 456: : 0batch [00:01, ?batch/s, Train loss=0.0137, Relative Train=0, Relative Val loss=4.37]
# Epoch 457: : 0batch [00:01, ?batch/s, Train loss=0.0127, Relative Train=0, Relative Val loss=4.17]
# Epoch 458: : 0batch [00:01, ?batch/s, Train loss=0.013, Relative Train=0, Relative Val loss=4.3]
# Epoch 459: : 0batch [00:01, ?batch/s, Train loss=0.0132, Relative Train=0, Relative Val loss=4.39]
# Epoch 460: : 0batch [00:02, ?batch/s, Train loss=0.0128, Relative Train=0, Relative Val loss=4.38]
# Epoch 461: : 0batch [00:02, ?batch/s, Train loss=0.0122, Relative Train=0, Relative Val loss=4.29]
# Epoch 462: : 0batch [00:01, ?batch/s, Train loss=0.0123, Relative Train=0, Relative Val loss=4.21]
# Epoch 463: : 0batch [00:01, ?batch/s, Train loss=0.0132, Relative Train=0, Relative Val loss=4.41]
# Epoch 464: : 0batch [00:01, ?batch/s, Train loss=0.0145, Relative Train=0, Relative Val loss=4.63]
# Epoch 465: : 0batch [00:01, ?batch/s, Train loss=0.0137, Relative Train=0, Relative Val loss=4.26]
# Epoch 466: : 0batch [00:01, ?batch/s, Train loss=0.0131, Relative Train=0, Relative Val loss=4.38]
# Epoch 467: : 0batch [00:01, ?batch/s, Train loss=0.0124, Relative Train=0, Relative Val loss=4.22]
# Epoch 468: : 0batch [00:02, ?batch/s, Train loss=0.0123, Relative Train=0, Relative Val loss=4.18]
# Epoch 469: : 0batch [00:01, ?batch/s, Train loss=0.0128, Relative Train=0, Relative Val loss=4.67]
# Epoch 470: : 0batch [00:01, ?batch/s, Train loss=0.0129, Relative Train=0, Relative Val loss=4.39]
# Epoch 471: : 0batch [00:01, ?batch/s, Train loss=0.0128, Relative Train=0, Relative Val loss=4.39]
# Epoch 472: : 0batch [00:01, ?batch/s, Train loss=0.0129, Relative Train=0, Relative Val loss=4.91]
# Epoch 473: : 0batch [00:01, ?batch/s, Train loss=0.014, Relative Train=0, Relative Val loss=4.62]
# Epoch 474: : 0batch [00:01, ?batch/s, Train loss=0.0134, Relative Train=0, Relative Val loss=4.36]
# Epoch 475: : 0batch [00:02, ?batch/s, Train loss=0.0124, Relative Train=0, Relative Val loss=4.22]
# Epoch 476: : 0batch [00:01, ?batch/s, Train loss=0.0122, Relative Train=0, Relative Val loss=4.34]
# Epoch 477: : 0batch [00:01, ?batch/s, Train loss=0.0129, Relative Train=0, Relative Val loss=4.34]
# Epoch 478: : 0batch [00:01, ?batch/s, Train loss=0.0133, Relative Train=0, Relative Val loss=4.27]
# Epoch 479: : 0batch [00:01, ?batch/s, Train loss=0.0128, Relative Train=0, Relative Val loss=4.34]
# Epoch 480: : 0batch [00:01, ?batch/s, Train loss=0.0124, Relative Train=0, Relative Val loss=4.27]
# Epoch 481: : 0batch [00:01, ?batch/s, Train loss=0.0123, Relative Train=0, Relative Val loss=4.23]
# Epoch 482: : 0batch [00:02, ?batch/s, Train loss=0.012, Relative Train=0, Relative Val loss=4.25]
# ...
# Epoch 720: : 0batch [00:01, ?batch/s, Train loss=0.00878, Relative Train=0, Relative Val loss=4.17]
# Epoch 721: : 0batch [00:01, ?batch/s, Train loss=0.00893, Relative Train=0, Relative Val loss=4.16]
# Epoch 722: : 0batch [00:02, ?batch/s, Train loss=0.00882, Relative Train=0, Relative Val loss=4.24]
# Epoch 723: : 0batch [00:01, ?batch/s, Train loss=0.00871, Relative Train=0, Relative Val loss=4.17]
# Epoch 724: : 0batch [00:01, ?batch/s, Train loss=0.00831, Relative Train=0, Relative Val loss=4.22]
# Epoch 725: : 0batch [00:01, ?batch/s, Train loss=0.00869, Relative Train=0, Relative Val loss=4.16]
# Epoch 726: : 0batch [00:01, ?batch/s, Train loss=0.009, Relative Train=0, Relative Val loss=4.26]
# Epoch 727: : 0batch [00:01, ?batch/s, Train loss=0.00875, Relative Train=0, Relative Val loss=4.26]
# Epoch 728: : 0batch [00:01, ?batch/s, Train loss=0.00883, Relative Train=0, Relative Val loss=4.18]
# Epoch 729: : 0batch [00:02, ?batch/s, Train loss=0.00892, Relative Train=0, Relative Val loss=4.21]
# Epoch 730: : 0batch [00:01, ?batch/s, Train loss=0.00942, Relative Train=0, Relative Val loss=4.27]
# Epoch 731: : 0batch [00:01, ?batch/s, Train loss=0.00859, Relative Train=0, Relative Val loss=4.18]
# Epoch 732: : 0batch [00:01, ?batch/s, Train loss=0.00833, Relative Train=0, Relative Val loss=4.19]
# Epoch 733: : 0batch [00:01, ?batch/s, Train loss=0.00818, Relative Train=0, Relative Val loss=4.19]
# Epoch 734: : 0batch [00:01, ?batch/s, Train loss=0.00814, Relative Train=0, Relative Val loss=4.19]
# Epoch 735: : 0batch [00:01, ?batch/s, Train loss=0.00873, Relative Train=0, Relative Val loss=4.17]
# Epoch 736: : 0batch [00:01, ?batch/s, Train loss=0.00853, Relative Train=0, Relative Val loss=4.18]
# Epoch 737: : 0batch [00:02, ?batch/s, Train loss=0.00865, Relative Train=0, Relative Val loss=4.16]
# Epoch 738: : 0batch [00:01, ?batch/s, Train loss=0.00838, Relative Train=0, Relative Val loss=4.26]
# Epoch 739: : 0batch [00:01, ?batch/s, Train loss=0.00842, Relative Train=0, Relative Val loss=4.21]
# Epoch 740: : 0batch [00:01, ?batch/s, Train loss=0.00837, Relative Train=0, Relative Val loss=4.2]
# Epoch 741: : 0batch [00:01, ?batch/s, Train loss=0.00863, Relative Train=0, Relative Val loss=4.16]
# Epoch 742: : 0batch [00:01, ?batch/s, Train loss=0.00896, Relative Train=0, Relative Val loss=4.2]
# Epoch 743: : 0batch [00:01, ?batch/s, Train loss=0.00881, Relative Train=0, Relative Val loss=4.2]
# Epoch 744: : 0batch [00:02, ?batch/s, Train loss=0.00849, Relative Train=0, Relative Val loss=4.18]
# Epoch 745: : 0batch [00:01, ?batch/s, Train loss=0.00816, Relative Train=0, Relative Val loss=4.18]
# Epoch 746: : 0batch [00:01, ?batch/s, Train loss=0.00843, Relative Train=0, Relative Val loss=4.24]
# Epoch 747: : 0batch [00:01, ?batch/s, Train loss=0.0091, Relative Train=0, Relative Val loss=4.33]
# Epoch 748: : 0batch [00:01, ?batch/s, Train loss=0.00894, Relative Train=0, Relative Val loss=4.19]
# Epoch 749: : 0batch [00:01, ?batch/s, Train loss=0.00834, Relative Train=0, Relative Val loss=4.22]
# Epoch 750: : 0batch [00:01, ?batch/s, Train loss=0.00831, Relative Train=0, Relative Val loss=4.16]
# Epoch 751: : 0batch [00:02, ?batch/s, Train loss=0.00864, Relative Train=0, Relative Val loss=4.21]
# Epoch 752: : 0batch [00:02, ?batch/s, Train loss=0.00869, Relative Train=0, Relative Val loss=4.21]
# Epoch 753: : 0batch [00:01, ?batch/s, Train loss=0.00814, Relative Train=0, Relative Val loss=4.15]
# Epoch 754: : 0batch [00:01, ?batch/s, Train loss=0.00839, Relative Train=0, Relative Val loss=4.19]
# Epoch 755: : 0batch [00:01, ?batch/s, Train loss=0.0083, Relative Train=0, Relative Val loss=4.16]
# Epoch 756: : 0batch [00:01, ?batch/s, Train loss=0.00849, Relative Train=0, Relative Val loss=4.18]
# Epoch 757: : 0batch [00:01, ?batch/s, Train loss=0.00838, Relative Train=0, Relative Val loss=4.16]
# Epoch 758: : 0batch [00:01, ?batch/s, Train loss=0.00858, Relative Train=0, Relative Val loss=4.2]
# Epoch 759: : 0batch [00:02, ?batch/s, Train loss=0.00838, Relative Train=0, Relative Val loss=4.19]
# Epoch 760: : 0batch [00:01, ?batch/s, Train loss=0.00828, Relative Train=0, Relative Val loss=4.3]
# Epoch 761: : 0batch [00:01, ?batch/s, Train loss=0.00851, Relative Train=0, Relative Val loss=4.18]
# Epoch 762: : 0batch [00:01, ?batch/s, Train loss=0.00823, Relative Train=0, Relative Val loss=4.19]
# Epoch 763: : 0batch [00:01, ?batch/s, Train loss=0.00792, Relative Train=0, Relative Val loss=4.15]
# Epoch 764: : 0batch [00:01, ?batch/s, Train loss=0.008, Relative Train=0, Relative Val loss=4.2]
# Epoch 765: : 0batch [00:01, ?batch/s, Train loss=0.00827, Relative Train=0, Relative Val loss=4.21]
# Epoch 766: : 0batch [00:02, ?batch/s, Train loss=0.00856, Relative Train=0, Relative Val loss=4.22]
# Epoch 767: : 0batch [00:01, ?batch/s, Train loss=0.00835, Relative Train=0, Relative Val loss=4.21]
# Epoch 768: : 0batch [00:01, ?batch/s, Train loss=0.00834, Relative Train=0, Relative Val loss=4.22]
# Epoch 769: : 0batch [00:01, ?batch/s, Train loss=0.00817, Relative Train=0, Relative Val loss=4.21]
# Epoch 770: : 0batch [00:01, ?batch/s, Train loss=0.00851, Relative Train=0, Relative Val loss=4.2]
# Epoch 771: : 0batch [00:01, ?batch/s, Train loss=0.00857, Relative Train=0, Relative Val loss=4.23]
# Epoch 772: : 0batch [00:01, ?batch/s, Train loss=0.00819, Relative Train=0, Relative Val loss=4.24]
# Epoch 773: : 0batch [00:02, ?batch/s, Train loss=0.00767, Relative Train=0, Relative Val loss=4.15]
# Epoch 774: : 0batch [00:01, ?batch/s, Train loss=0.00822, Relative Train=0, Relative Val loss=4.17]
# Epoch 775: : 0batch [00:01, ?batch/s, Train loss=0.00796, Relative Train=0, Relative Val loss=4.24]
# Epoch 776: : 0batch [00:01, ?batch/s, Train loss=0.00852, Relative Train=0, Relative Val loss=4.18]
# Epoch 777: : 0batch [00:01, ?batch/s, Train loss=0.00806, Relative Train=0, Relative Val loss=4.15]
# Epoch 778: : 0batch [00:01, ?batch/s, Train loss=0.0081, Relative Train=0, Relative Val loss=4.22]
# Epoch 779: : 0batch [00:01, ?batch/s, Train loss=0.00848, Relative Train=0, Relative Val loss=4.25]
# Epoch 780: : 0batch [00:01, ?batch/s, Train loss=0.00842, Relative Train=0, Relative Val loss=4.18]
# Epoch 781: : 0batch [00:02, ?batch/s, Train loss=0.00795, Relative Train=0, Relative Val loss=4.16]
# Epoch 782: : 0batch [00:01, ?batch/s, Train loss=0.00787, Relative Train=0, Relative Val loss=4.21]
# Epoch 783: : 0batch [00:01, ?batch/s, Train loss=0.0079, Relative Train=0, Relative Val loss=4.16]
# Epoch 784: : 0batch [00:01, ?batch/s, Train loss=0.00812, Relative Train=0, Relative Val loss=4.2]
# Epoch 785: : 0batch [00:01, ?batch/s, Train loss=0.00803, Relative Train=0, Relative Val loss=4.17]
# Epoch 786: : 0batch [00:01, ?batch/s, Train loss=0.00812, Relative Train=0, Relative Val loss=4.22]
# Epoch 787: : 0batch [00:01, ?batch/s, Train loss=0.00815, Relative Train=0, Relative Val loss=4.15]
# Epoch 788: : 0batch [00:02, ?batch/s, Train loss=0.00849, Relative Train=0, Relative Val loss=4.16]
# Epoch 789: : 0batch [00:01, ?batch/s, Train loss=0.00806, Relative Train=0, Relative Val loss=4.15]
# Epoch 790: : 0batch [00:01, ?batch/s, Train loss=0.00763, Relative Train=0, Relative Val loss=4.17]
# Epoch 791: : 0batch [00:01, ?batch/s, Train loss=0.00777, Relative Train=0, Relative Val loss=4.24]
# Epoch 792: : 0batch [00:01, ?batch/s, Train loss=0.00799, Relative Train=0, Relative Val loss=4.16]
# Epoch 793: : 0batch [00:01, ?batch/s, Train loss=0.00772, Relative Train=0, Relative Val loss=4.16]
# Epoch 794: : 0batch [00:01, ?batch/s, Train loss=0.00844, Relative Train=0, Relative Val loss=4.18]
# Epoch 795: : 0batch [00:01, ?batch/s, Train loss=0.00857, Relative Train=0, Relative Val loss=4.17]
# Epoch 796: : 0batch [00:02, ?batch/s, Train loss=0.00778, Relative Train=0, Relative Val loss=4.2]
# Epoch 797: : 0batch [00:01, ?batch/s, Train loss=0.00789, Relative Train=0, Relative Val loss=4.19]
# Epoch 798: : 0batch [00:01, ?batch/s, Train loss=0.00803, Relative Train=0, Relative Val loss=4.16]
# Epoch 799: : 0batch [00:01, ?batch/s, Train loss=0.00795, Relative Train=0, Relative Val loss=4.16]
# Epoch 800: : 0batch [00:01, ?batch/s, Train loss=0.00769, Relative Train=0, Relative Val loss=4.24]
# Epoch 801: : 0batch [00:01, ?batch/s, Train loss=0.00793, Relative Train=0, Relative Val loss=4.23]
# Epoch 802: : 0batch [00:01, ?batch/s, Train loss=0.00783, Relative Train=0, Relative Val loss=4.22]
# Epoch 803: : 0batch [00:02, ?batch/s, Train loss=0.00747, Relative Train=0, Relative Val loss=4.17]
# Epoch 804: : 0batch [00:01, ?batch/s, Train loss=0.00785, Relative Train=0, Relative Val loss=4.15]
# Epoch 805: : 0batch [00:01, ?batch/s, Train loss=0.00782, Relative Train=0, Relative Val loss=4.21]
# Epoch 806: : 0batch [00:01, ?batch/s, Train loss=0.00801, Relative Train=0, Relative Val loss=4.23]
# Epoch 807: : 0batch [00:01, ?batch/s, Train loss=0.00782, Relative Train=0, Relative Val loss=4.22]
# Epoch 808: : 0batch [00:01, ?batch/s, Train loss=0.00808, Relative Train=0, Relative Val loss=4.22]
# Epoch 809: : 0batch [00:01, ?batch/s, Train loss=0.00801, Relative Train=0, Relative Val loss=4.15]
# Epoch 810: : 0batch [00:02, ?batch/s, Train loss=0.00766, Relative Train=0, Relative Val loss=4.2]
# Epoch 811: : 0batch [00:01, ?batch/s, Train loss=0.0078, Relative Train=0, Relative Val loss=4.37]
# Epoch 812: : 0batch [00:01, ?batch/s, Train loss=0.00801, Relative Train=0, Relative Val loss=4.24]
# Epoch 813: : 0batch [00:01, ?batch/s, Train loss=0.00804, Relative Train=0, Relative Val loss=4.18]
# Epoch 814: : 0batch [00:01, ?batch/s, Train loss=0.00817, Relative Train=0, Relative Val loss=4.22]
# Epoch 815: : 0batch [00:01, ?batch/s, Train loss=0.00781, Relative Train=0, Relative Val loss=4.21]
# Epoch 816: : 0batch [00:01, ?batch/s, Train loss=0.0083, Relative Train=0, Relative Val loss=4.15]
# Epoch 817: : 0batch [00:01, ?batch/s, Train loss=0.00809, Relative Train=0, Relative Val loss=4.18]
# Epoch 818: : 0batch [00:02, ?batch/s, Train loss=0.00786, Relative Train=0, Relative Val loss=4.2]
# Epoch 819: : 0batch [00:01, ?batch/s, Train loss=0.0078, Relative Train=0, Relative Val loss=4.19]
# Epoch 820: : 0batch [00:01, ?batch/s, Train loss=0.00764, Relative Train=0, Relative Val loss=4.15]
# Epoch 821: : 0batch [00:01, ?batch/s, Train loss=0.0077, Relative Train=0, Relative Val loss=4.23]
# Epoch 822: : 0batch [00:01, ?batch/s, Train loss=0.00819, Relative Train=0, Relative Val loss=4.17]
# Epoch 823: : 0batch [00:01, ?batch/s, Train loss=0.00783, Relative Train=0, Relative Val loss=4.21]
# Epoch 824: : 0batch [00:01, ?batch/s, Train loss=0.00825, Relative Train=0, Relative Val loss=4.24]
# Epoch 825: : 0batch [00:02, ?batch/s, Train loss=0.00762, Relative Train=0, Relative Val loss=4.19]
# Epoch 826: : 0batch [00:01, ?batch/s, Train loss=0.00806, Relative Train=0, Relative Val loss=4.19]
# Epoch 827: : 0batch [00:01, ?batch/s, Train loss=0.00755, Relative Train=0, Relative Val loss=4.16]
# Epoch 828: : 0batch [00:01, ?batch/s, Train loss=0.00784, Relative Train=0, Relative Val loss=4.23]
# Epoch 829: : 0batch [00:01, ?batch/s, Train loss=0.00761, Relative Train=0, Relative Val loss=4.2]
# Epoch 830: : 0batch [00:01, ?batch/s, Train loss=0.00767, Relative Train=0, Relative Val loss=4.18]
# Epoch 831: : 0batch [00:01, ?batch/s, Train loss=0.00789, Relative Train=0, Relative Val loss=4.35]
# Epoch 832: : 0batch [00:02, ?batch/s, Train loss=0.00769, Relative Train=0, Relative Val loss=4.22]
# Epoch 833: : 0batch [00:02, ?batch/s, Train loss=0.0079, Relative Train=0, Relative Val loss=4.2]
# Epoch 834: : 0batch [00:01, ?batch/s, Train loss=0.00801, Relative Train=0, Relative Val loss=4.19]
# Epoch 835: : 0batch [00:01, ?batch/s, Train loss=0.00779, Relative Train=0, Relative Val loss=4.23]
# Epoch 836: : 0batch [00:01, ?batch/s, Train loss=0.0077, Relative Train=0, Relative Val loss=4.18]
# Epoch 837: : 0batch [00:01, ?batch/s, Train loss=0.00824, Relative Train=0, Relative Val loss=4.17]
# Epoch 838: : 0batch [00:01, ?batch/s, Train loss=0.00813, Relative Train=0, Relative Val loss=4.16]
# Epoch 839: : 0batch [00:01, ?batch/s, Train loss=0.00799, Relative Train=0, Relative Val loss=4.26]
# Epoch 840: : 0batch [00:02, ?batch/s, Train loss=0.00831, Relative Train=0, Relative Val loss=4.21]
# Epoch 841: : 0batch [00:01, ?batch/s, Train loss=0.00797, Relative Train=0, Relative Val loss=4.19]
# Epoch 842: : 0batch [00:01, ?batch/s, Train loss=0.00762, Relative Train=0, Relative Val loss=4.17]
# Epoch 843: : 0batch [00:01, ?batch/s, Train loss=0.00808, Relative Train=0, Relative Val loss=4.23]
# Epoch 844: : 0batch [00:01, ?batch/s, Train loss=0.00778, Relative Train=0, Relative Val loss=4.18]
# Epoch 845: : 0batch [00:01, ?batch/s, Train loss=0.0079, Relative Train=0, Relative Val loss=4.18]
# Epoch 846: : 0batch [00:01, ?batch/s, Train loss=0.00738, Relative Train=0, Relative Val loss=4.17]
# Epoch 847: : 0batch [00:02, ?batch/s, Train loss=0.00742, Relative Train=0, Relative Val loss=4.22]
# Epoch 848: : 0batch [00:01, ?batch/s, Train loss=0.00742, Relative Train=0, Relative Val loss=4.2]
# Epoch 849: : 0batch [00:01, ?batch/s, Train loss=0.00757, Relative Train=0, Relative Val loss=4.26]
# Epoch 850: : 0batch [00:01, ?batch/s, Train loss=0.00785, Relative Train=0, Relative Val loss=4.19]
# Epoch 851: : 0batch [00:01, ?batch/s, Train loss=0.00733, Relative Train=0, Relative Val loss=4.17]
# Epoch 852: : 0batch [00:01, ?batch/s, Train loss=0.00742, Relative Train=0, Relative Val loss=4.21]
# Epoch 853: : 0batch [00:01, ?batch/s, Train loss=0.00788, Relative Train=0, Relative Val loss=4.16]
# Epoch 854: : 0batch [00:02, ?batch/s, Train loss=0.00753, Relative Train=0, Relative Val loss=4.17]
# Epoch 855: : 0batch [00:02, ?batch/s, Train loss=0.00782, Relative Train=0, Relative Val loss=4.3]
# Epoch 856: : 0batch [00:01, ?batch/s, Train loss=0.0075, Relative Train=0, Relative Val loss=4.16]
# Epoch 857: : 0batch [00:01, ?batch/s, Train loss=0.00794, Relative Train=0, Relative Val loss=4.18]
# Epoch 858: : 0batch [00:01, ?batch/s, Train loss=0.00774, Relative Train=0, Relative Val loss=4.15]
# Epoch 859: : 0batch [00:01, ?batch/s, Train loss=0.00754, Relative Train=0, Relative Val loss=4.18]
# Epoch 860: : 0batch [00:01, ?batch/s, Train loss=0.0077, Relative Train=0, Relative Val loss=4.17]
# Epoch 861: : 0batch [00:01, ?batch/s, Train loss=0.00762, Relative Train=0, Relative Val loss=4.18]
# Epoch 862: : 0batch [00:02, ?batch/s, Train loss=0.00718, Relative Train=0, Relative Val loss=4.18]
# Epoch 863: : 0batch [00:01, ?batch/s, Train loss=0.00719, Relative Train=0, Relative Val loss=4.18]
# Epoch 864: : 0batch [00:01, ?batch/s, Train loss=0.00721, Relative Train=0, Relative Val loss=4.17]
# Epoch 865: : 0batch [00:01, ?batch/s, Train loss=0.00724, Relative Train=0, Relative Val loss=4.16]
# Epoch 866: : 0batch [00:01, ?batch/s, Train loss=0.00736, Relative Train=0, Relative Val loss=4.2]
# Epoch 867: : 0batch [00:01, ?batch/s, Train loss=0.00732, Relative Train=0, Relative Val loss=4.17]
# Epoch 868: : 0batch [00:01, ?batch/s, Train loss=0.00789, Relative Train=0, Relative Val loss=4.16]
# Epoch 869: : 0batch [00:02, ?batch/s, Train loss=0.00832, Relative Train=0, Relative Val loss=4.21]
# Epoch 870: : 0batch [00:01, ?batch/s, Train loss=0.00761, Relative Train=0, Relative Val loss=4.18]
# Epoch 871: : 0batch [00:01, ?batch/s, Train loss=0.00765, Relative Train=0, Relative Val loss=4.19]
# Epoch 872: : 0batch [00:01, ?batch/s, Train loss=0.00746, Relative Train=0, Relative Val loss=4.18]
# Epoch 873: : 0batch [00:01, ?batch/s, Train loss=0.0072, Relative Train=0, Relative Val loss=4.18]
# Epoch 874: : 0batch [00:01, ?batch/s, Train loss=0.00732, Relative Train=0, Relative Val loss=4.17]
# Epoch 875: : 0batch [00:01, ?batch/s, Train loss=0.0079, Relative Train=0, Relative Val loss=4.19]
# Epoch 876: : 0batch [00:01, ?batch/s, Train loss=0.00795, Relative Train=0, Relative Val loss=4.19]
# Epoch 877: : 0batch [00:02, ?batch/s, Train loss=0.00774, Relative Train=0, Relative Val loss=4.24]
# Epoch 878: : 0batch [00:01, ?batch/s, Train loss=0.0079, Relative Train=0, Relative Val loss=4.19]
# Epoch 879: : 0batch [00:01, ?batch/s, Train loss=0.00736, Relative Train=0, Relative Val loss=4.21]
# Early Stopping

# %%
rm -rf ~/.cache/torch_extensions/

# %%
pip install ninja
# Out:
# Collecting ninja
#   Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1.4
