# %%
from __future__ import annotations

import pickle
from pathlib import Path
from timeit import default_timer

import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset
import logging
import h5py

# %%
class GatingTransformer(nn.Module):
    """
    Transforms the original input to match target resolution and channels
    for use in the gating mechanism at different layers
    """
    def __init__(self, in_channels, out_channels, target_size):
        super(GatingTransformer, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.target_size = target_size

        # Transform input channels to match layer's channel requirement
        self.channel_transform = nn.Conv1d(
            in_channels=in_channels,
            out_channels=out_channels,
            kernel_size=1
        )

    def forward(self, x):
        # Resize input to target resolution
        x = F.interpolate(x, size=self.target_size, mode='linear', align_corners=False)
        # Transform channels
        x = self.channel_transform(x)
        return x

class DLGN_Gate(nn.Module):
    """
    Implements the gating mechanism for DLGN
    G_l(x) = σ(βU_l^T x)
    """
    def __init__(self, in_channels, out_channels, target_size, beta=1.0):
        super(DLGN_Gate, self).__init__()
        self.beta = beta
        self.target_size = target_size
        self.transformer = GatingTransformer(in_channels, out_channels, target_size)
        self.gate_weights = nn.Conv1d(
            in_channels=out_channels,
            out_channels=out_channels,
            kernel_size=3,
            padding=1
        )

    def forward(self, original_input):
        # Transform original input to match current layer dimensions
        x = self.transformer(original_input)
        # Apply gating weights (U_l^T x)
        x = self.gate_weights(x)
        # Apply sigmoid activation with beta parameter
        return torch.sigmoid(self.beta * x)

class DLGN_Layer(nn.Module):
    """
    Implements the DLGN activation mechanism
    ψ^(l)(x) = G_l(x) ⊙ (W_l^T ψ^(l-1)(x))
    """
    def __init__(self, in_size, out_size):
        super(DLGN_Layer, self).__init__()
        self.in_size = in_size
        self.out_size = out_size

    def forward(self, x, gate):
        # Resize input to desired output size (double size first as in original CNO_LReLu)
        x = F.interpolate(x.unsqueeze(2), size=(1, 2 * self.in_size), mode="bicubic", antialias=True)

        # Make sure gate has the right shape for broadcasting
        if gate.shape != x.shape:
            # Reshape gate to match the interpolated x
            gate = gate.unsqueeze(2) if gate.dim() == 3 else gate
            gate = F.interpolate(gate, size=x.size()[2:], mode="nearest")

        # Element-wise multiplication with gate
        x = gate * x

        # Resize to final output size
        x = F.interpolate(x, size=(1, self.out_size), mode="bicubic", antialias=True)
        return x[:,:,0]

# %%
class CNOBlock_DLGN(nn.Module):
    """
    Modified CNOBlock to use DLGN instead of traditional activation
    """
    def __init__(self,
                 in_channels,
                 out_channels,
                 in_size,
                 out_size,
                 original_channels,
                 beta=1.0,
                 use_bn=True):
        super(CNOBlock_DLGN, self).__init__()

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.in_size = in_size
        self.out_size = out_size

        # Convolution layer
        self.convolution = torch.nn.Conv1d(in_channels=self.in_channels,
                                          out_channels=self.out_channels,
                                          kernel_size=3,
                                          padding=1)

        # Batch normalization (optional)
        if use_bn:
             self.batch_norm = nn.BatchNorm1d(self.out_channels)
        else:
             self.batch_norm = nn.Identity()

        # DLGN components
        self.gating = DLGN_Gate(original_channels, out_channels, out_size, beta)
        self.dlgn_layer = DLGN_Layer(in_size=self.in_size, out_size=self.out_size)

    def forward(self, x, original_input):
        # Apply convolution and batch norm
        x = self.convolution(x)
        x = self.batch_norm(x)

        # Get gating signal from original input
        gate = self.gating(original_input)

        # Apply DLGN layer
        return self.dlgn_layer(x, gate)

class LiftProjectBlock_DLGN(nn.Module):
    """
    Modified LiftProjectBlock to use DLGN
    """
    def __init__(self,
                in_channels,
                out_channels,
                size,
                original_channels,
                beta=1.0,
                latent_dim=64):
        super(LiftProjectBlock_DLGN, self).__init__()

        self.inter_CNOBlock = CNOBlock_DLGN(in_channels=in_channels,
                                           out_channels=latent_dim,
                                           in_size=size,
                                           out_size=size,
                                           original_channels=original_channels,
                                           beta=beta,
                                           use_bn=False)

        self.convolution = torch.nn.Conv1d(in_channels=latent_dim,
                                          out_channels=out_channels,
                                          kernel_size=3,
                                          padding=1)

    def forward(self, x, original_input):
        x = self.inter_CNOBlock(x, original_input)
        x = self.convolution(x)
        return x

class ResidualBlock_DLGN(nn.Module):
    """
    Modified ResidualBlock to use DLGN
    """
    def __init__(self,
                 channels,
                 size,
                 original_channels,
                 beta=1.0,
                 use_bn=True):
        super(ResidualBlock_DLGN, self).__init__()

        self.channels = channels
        self.size = size

        # First convolution path
        self.convolution1 = torch.nn.Conv1d(in_channels=self.channels,
                                           out_channels=self.channels,
                                           kernel_size=3,
                                           padding=1)

        # Second convolution path
        self.convolution2 = torch.nn.Conv1d(in_channels=self.channels,
                                           out_channels=self.channels,
                                           kernel_size=3,
                                           padding=1)

        # Batch normalization (optional)
        if use_bn:
            self.batch_norm1 = nn.BatchNorm1d(self.channels)
            self.batch_norm2 = nn.BatchNorm1d(self.channels)
        else:
            self.batch_norm1 = nn.Identity()
            self.batch_norm2 = nn.Identity()

        # DLGN components
        self.gating1 = DLGN_Gate(original_channels, channels, size, beta)
        self.gating2 = DLGN_Gate(original_channels, channels, size, beta)
        self.dlgn_layer1 = DLGN_Layer(in_size=self.size, out_size=self.size)
        self.dlgn_layer2 = DLGN_Layer(in_size=self.size, out_size=self.size)

    def forward(self, x, original_input):
        identity = x

        # First convolution path
        out = self.convolution1(x)
        out = self.batch_norm1(out)

        # Apply first DLGN layer
        gate1 = self.gating1(original_input)
        out = self.dlgn_layer1(out, gate1)

        # Second convolution path
        out = self.convolution2(out)
        out = self.batch_norm2(out)

        # Apply second DLGN layer
        gate2 = self.gating2(original_input)
        out = self.dlgn_layer2(out, gate2)

        # Apply residual connection
        return identity + out

class ResNet_DLGN(nn.Module):
    """
    Modified ResNet to use DLGN
    """
    def __init__(self,
                 channels,
                 size,
                 original_channels,
                 num_blocks,
                 beta=1.0,
                 use_bn=True):
        super(ResNet_DLGN, self).__init__()

        self.channels = channels
        self.size = size
        self.num_blocks = num_blocks
        self.original_channels = original_channels

        # Create resnet blocks
        self.res_blocks = nn.ModuleList([
            ResidualBlock_DLGN(
                channels=channels,
                size=size,
                original_channels=original_channels,
                beta=beta,
                use_bn=use_bn
            ) for _ in range(num_blocks)
        ])

    def forward(self, x, original_input):
        for block in self.res_blocks:
            x = block(x, original_input)
        return x

# %%
class CNO1d(nn.Module):
    def __init__(self,
                 num_channels,           # Number of input/output channels
                 width=64,               # Base width for the network
                 initial_step=10,        # Number of initial timesteps
                 size=None,              # Spatial size of the domain
                 N_layers=4,             # Number of (D) or (U) blocks in the network
                 N_res=4,                # Number of (R) blocks per level (except the neck)
                 N_res_neck=4,           # Number of (R) blocks in the neck
                 channel_multiplier=16,  # How the number of channels evolve
                 use_bn=True             # Add BN? We do not add BN in lifting/projection layer
                ):
        super(CNO1d, self).__init__()

        # Store parameters
        self.num_channels = num_channels
        self.initial_step = initial_step
        self.width = width

        # Determine spatial size if not provided
        if size is None:
            size = 128  # Default spatial size

        # Create the CNO1d architecture
        self.model = CNO1d_DLGN(
            in_dim=initial_step * num_channels + 1,  # Input: initial_step channels + grid
            out_dim=num_channels,                    # Output: predict next channel values
            size=size,
            N_layers=N_layers,
            N_res=N_res,
            N_res_neck=N_res_neck,
            channel_multiplier=channel_multiplier,
            use_bn=use_bn
        )

    def forward(self, x, grid):
        # x dim = [b, x1, t*v] - same input format as FNO1d
        # Combine x and grid to match CNO1d_Core input format
        inputs = torch.cat((x, grid), dim=-1)  # concatenate along feature dimension

        # Reshape for CNO: [batch, channels, spatial_dim]
        batch_size = inputs.shape[0]
        spatial_dim = inputs.shape[1]
        inputs = inputs.permute(0, 2, 1)  # [batch, features, spatial]

        # Forward pass through CNO
        out = self.model(inputs)

        # Reshape back to expected output format: [batch, spatial, channels, 1]
        out = out.permute(0, 2, 1)  # [batch, spatial, channels]
        out = out.unsqueeze(-2)     # [batch, spatial, 1, channels]

        return out

class CNO1d_DLGN(nn.Module):
    """
    Modified CNO1d to use DLGN framework
    """
    def __init__(self,
                 in_dim,                    # Number of input channels
                 out_dim,                   # Number of output channels
                 size,                      # Input and Output spatial size
                 N_layers,                  # Number of (D) or (U) blocks
                 N_res=4,                   # Number of (R) blocks per level
                 N_res_neck=4,              # Number of (R) blocks in the neck
                 channel_multiplier=16,     # Channel evolution factor
                 beta=1.0,                  # Beta parameter for DLGN
                 use_bn=True,               # Use batch normalization
                ):
        super(CNO1d_DLGN, self).__init__()

        self.N_layers = int(N_layers)
        self.lift_dim = channel_multiplier//2
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.channel_multiplier = channel_multiplier
        self.beta = beta

        ######## Num of channels/features - evolution ########
        self.encoder_features = [self.lift_dim]
        for i in range(self.N_layers):
            self.encoder_features.append(2 ** i * self.channel_multiplier)

        self.decoder_features_in = self.encoder_features[1:]
        self.decoder_features_in.reverse()
        self.decoder_features_out = self.encoder_features[:-1]
        self.decoder_features_out.reverse()

        for i in range(1, self.N_layers):
            self.decoder_features_in[i] = 2 * self.decoder_features_in[i]

        ######## Spatial sizes of channels - evolution ########
        self.encoder_sizes = []
        self.decoder_sizes = []
        for i in range(self.N_layers + 1):
            self.encoder_sizes.append(size // 2 ** i)
            self.decoder_sizes.append(size // 2 ** (self.N_layers - i))

        ######## Define Lift and Project blocks ########
        self.lift = LiftProjectBlock_DLGN(
            in_channels=in_dim,
            out_channels=self.encoder_features[0],
            size=size,
            original_channels=in_dim,
            beta=beta
        )

        self.project = LiftProjectBlock_DLGN(
            in_channels=self.encoder_features[0] + self.decoder_features_out[-1],
            out_channels=out_dim,
            size=size,
            original_channels=in_dim,
            beta=beta
        )

        ######## Define Encoder, ED Linker and Decoder networks ########
        self.encoder = nn.ModuleList([
            CNOBlock_DLGN(
                in_channels=self.encoder_features[i],
                out_channels=self.encoder_features[i+1],
                in_size=self.encoder_sizes[i],
                out_size=self.encoder_sizes[i+1],
                original_channels=in_dim,
                beta=beta,
                use_bn=use_bn
            ) for i in range(self.N_layers)
        ])

        # ED expansion blocks
        self.ED_expansion = nn.ModuleList([
            CNOBlock_DLGN(
                in_channels=self.encoder_features[i],
                out_channels=self.encoder_features[i],
                in_size=self.encoder_sizes[i],
                out_size=self.decoder_sizes[self.N_layers - i],
                original_channels=in_dim,
                beta=beta,
                use_bn=use_bn
            ) for i in range(self.N_layers + 1)
        ])

        # Decoder blocks
        self.decoder = nn.ModuleList([
            CNOBlock_DLGN(
                in_channels=self.decoder_features_in[i],
                out_channels=self.decoder_features_out[i],
                in_size=self.decoder_sizes[i],
                out_size=self.decoder_sizes[i+1],
                original_channels=in_dim,
                beta=beta,
                use_bn=use_bn
            ) for i in range(self.N_layers)
        ])

        ######## Define ResNets Blocks ########
        self.res_nets = nn.ModuleList([
            ResNet_DLGN(
                channels=self.encoder_features[l],
                size=self.encoder_sizes[l],
                original_channels=in_dim,
                num_blocks=N_res,
                beta=beta,
                use_bn=use_bn
            ) for l in range(self.N_layers)
        ])

        # Bottleneck ResNet
        self.res_net_neck = ResNet_DLGN(
            channels=self.encoder_features[self.N_layers],
            size=self.encoder_sizes[self.N_layers],
            original_channels=in_dim,
            num_blocks=N_res_neck,
            beta=beta,
            use_bn=use_bn
        )

    def forward(self, x):
        # Store original input for gating
        original_input = x.clone()

        # Execute lift
        x = self.lift(x, original_input)
        skip = []

        # Execute encoder
        for i in range(self.N_layers):
            # Apply ResNet & save result
            y = self.res_nets[i](x, original_input)
            skip.append(y)

            # Apply (D) block
            x = self.encoder[i](x, original_input)

        # Apply bottleneck ResNet
        x = self.res_net_neck(x, original_input)

        # Execute decoder
        for i in range(self.N_layers):
            # Apply (I) block (ED_expansion) & cat if needed
            if i == 0:
                x = self.ED_expansion[self.N_layers - i](x, original_input)  # Bottleneck: no cat
            else:
                exp_skip = self.ED_expansion[self.N_layers - i](skip[-i], original_input)
                x = torch.cat((x, exp_skip), 1)

            # Apply (U) block
            x = self.decoder[i](x, original_input)

        # Cat & execute projection
        exp_skip = self.ED_expansion[0](skip[0], original_input)
        x = torch.cat((x, exp_skip), 1)
        x = self.project(x, original_input)

        return x

# %%
model = CNO1d(
    num_channels=num_channels,
    width=channel_multiplier,  # Use channel_multiplier as width
    initial_step=initial_step,
    size=size,
    N_layers=N_layers,
    N_res=N_res,
    N_res_neck=N_res_neck,
    channel_multiplier=channel_multiplier,
    use_bn=True
)

# %%
import torch
from torch.fx import symbolic_trace

# %%
traced = symbolic_trace(model)

# Print the graph of the forward pass
print(traced.graph)
# Out:
# graph():
#     %x : [num_users=1] = placeholder[target=x]
#     %grid : [num_users=1] = placeholder[target=grid]
#     %cat : [num_users=3] = call_function[target=torch.cat](args = ((%x, %grid),), kwargs = {dim: -1})
#     %getattr_1 : [num_users=1] = call_function[target=builtins.getattr](args = (%cat, shape), kwargs = {})
#     %getitem : [num_users=0] = call_function[target=operator.getitem](args = (%getattr_1, 0), kwargs = {})
#     %getattr_2 : [num_users=1] = call_function[target=builtins.getattr](args = (%cat, shape), kwargs = {})
#     %getitem_1 : [num_users=0] = call_function[target=operator.getitem](args = (%getattr_2, 1), kwargs = {})
#     %permute : [num_users=2] = call_method[target=permute](args = (%cat, 0, 2, 1), kwargs = {})
#     %clone : [num_users=55] = call_method[target=clone](args = (%permute,), kwargs = {})
#     %model_lift_inter_cnoblock_convolution : [num_users=1] = call_module[target=model.lift.inter_CNOBlock.convolution](args = (%permute,), kwargs = {})
#     %model_lift_inter_cnoblock_batch_norm : [num_users=1] = call_module[target=model.lift.inter_CNOBlock.batch_norm](args = (%model_lift_inter_cnoblock_convolution,), kwargs = {})
#     %interpolate : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_lift_inter_cnoblock_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.lift.inter_CNOBlock.gating.transformer.channel_transform](args = (%interpolate,), kwargs = {})
#     %model_lift_inter_cnoblock_gating_gate_weights : [num_users=1] = call_module[target=model.lift.inter_CNOBlock.gating.gate_weights](args = (%model_lift_inter_cnoblock_gating_transformer_channel_transform,), kwargs = {})
#     %mul : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_lift_inter_cnoblock_gating_gate_weights), kwargs = {})
#     %sigmoid : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul,), kwargs = {})
#     %unsqueeze : [num_users=1] = call_method[target=unsqueeze](args = (%model_lift_inter_cnoblock_batch_norm, 2), kwargs = {})
#     %interpolate_1 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_1 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid, %interpolate_1), kwargs = {})
#     %interpolate_2 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_1,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_2 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_2, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_lift_convolution : [num_users=3] = call_module[target=model.lift.convolution](args = (%getitem_2,), kwargs = {})
#     %model_res_nets_0_res_blocks_0_convolution1 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.0.convolution1](args = (%model_lift_convolution,), kwargs = {})
#     %model_res_nets_0_res_blocks_0_batch_norm1 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.0.batch_norm1](args = (%model_res_nets_0_res_blocks_0_convolution1,), kwargs = {})
#     %interpolate_3 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_0_res_blocks_0_gating1_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.0.gating1.transformer.channel_transform](args = (%interpolate_3,), kwargs = {})
#     %model_res_nets_0_res_blocks_0_gating1_gate_weights : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.0.gating1.gate_weights](args = (%model_res_nets_0_res_blocks_0_gating1_transformer_channel_transform,), kwargs = {})
#     %mul_2 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_0_res_blocks_0_gating1_gate_weights), kwargs = {})
#     %sigmoid_1 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_2,), kwargs = {})
#     %unsqueeze_1 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_0_res_blocks_0_batch_norm1, 2), kwargs = {})
#     %interpolate_4 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_1,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_3 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_1, %interpolate_4), kwargs = {})
#     %interpolate_5 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_3,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_3 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_5, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_0_res_blocks_0_convolution2 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.0.convolution2](args = (%getitem_3,), kwargs = {})
#     %model_res_nets_0_res_blocks_0_batch_norm2 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.0.batch_norm2](args = (%model_res_nets_0_res_blocks_0_convolution2,), kwargs = {})
#     %interpolate_6 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_0_res_blocks_0_gating2_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.0.gating2.transformer.channel_transform](args = (%interpolate_6,), kwargs = {})
#     %model_res_nets_0_res_blocks_0_gating2_gate_weights : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.0.gating2.gate_weights](args = (%model_res_nets_0_res_blocks_0_gating2_transformer_channel_transform,), kwargs = {})
#     %mul_4 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_0_res_blocks_0_gating2_gate_weights), kwargs = {})
#     %sigmoid_2 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_4,), kwargs = {})
#     %unsqueeze_2 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_0_res_blocks_0_batch_norm2, 2), kwargs = {})
#     %interpolate_7 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_2,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_5 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_2, %interpolate_7), kwargs = {})
#     %interpolate_8 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_5,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_4 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_8, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %add : [num_users=2] = call_function[target=operator.add](args = (%model_lift_convolution, %getitem_4), kwargs = {})
#     %model_res_nets_0_res_blocks_1_convolution1 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.1.convolution1](args = (%add,), kwargs = {})
#     %model_res_nets_0_res_blocks_1_batch_norm1 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.1.batch_norm1](args = (%model_res_nets_0_res_blocks_1_convolution1,), kwargs = {})
#     %interpolate_9 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_0_res_blocks_1_gating1_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.1.gating1.transformer.channel_transform](args = (%interpolate_9,), kwargs = {})
#     %model_res_nets_0_res_blocks_1_gating1_gate_weights : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.1.gating1.gate_weights](args = (%model_res_nets_0_res_blocks_1_gating1_transformer_channel_transform,), kwargs = {})
#     %mul_6 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_0_res_blocks_1_gating1_gate_weights), kwargs = {})
#     %sigmoid_3 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_6,), kwargs = {})
#     %unsqueeze_3 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_0_res_blocks_1_batch_norm1, 2), kwargs = {})
#     %interpolate_10 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_3,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_7 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_3, %interpolate_10), kwargs = {})
#     %interpolate_11 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_7,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_5 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_11, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_0_res_blocks_1_convolution2 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.1.convolution2](args = (%getitem_5,), kwargs = {})
#     %model_res_nets_0_res_blocks_1_batch_norm2 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.1.batch_norm2](args = (%model_res_nets_0_res_blocks_1_convolution2,), kwargs = {})
#     %interpolate_12 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_0_res_blocks_1_gating2_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.1.gating2.transformer.channel_transform](args = (%interpolate_12,), kwargs = {})
#     %model_res_nets_0_res_blocks_1_gating2_gate_weights : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.1.gating2.gate_weights](args = (%model_res_nets_0_res_blocks_1_gating2_transformer_channel_transform,), kwargs = {})
#     %mul_8 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_0_res_blocks_1_gating2_gate_weights), kwargs = {})
#     %sigmoid_4 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_8,), kwargs = {})
#     %unsqueeze_4 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_0_res_blocks_1_batch_norm2, 2), kwargs = {})
#     %interpolate_13 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_4,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_9 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_4, %interpolate_13), kwargs = {})
#     %interpolate_14 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_9,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_6 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_14, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %add_1 : [num_users=2] = call_function[target=operator.add](args = (%add, %getitem_6), kwargs = {})
#     %model_res_nets_0_res_blocks_2_convolution1 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.2.convolution1](args = (%add_1,), kwargs = {})
#     %model_res_nets_0_res_blocks_2_batch_norm1 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.2.batch_norm1](args = (%model_res_nets_0_res_blocks_2_convolution1,), kwargs = {})
#     %interpolate_15 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_0_res_blocks_2_gating1_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.2.gating1.transformer.channel_transform](args = (%interpolate_15,), kwargs = {})
#     %model_res_nets_0_res_blocks_2_gating1_gate_weights : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.2.gating1.gate_weights](args = (%model_res_nets_0_res_blocks_2_gating1_transformer_channel_transform,), kwargs = {})
#     %mul_10 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_0_res_blocks_2_gating1_gate_weights), kwargs = {})
#     %sigmoid_5 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_10,), kwargs = {})
#     %unsqueeze_5 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_0_res_blocks_2_batch_norm1, 2), kwargs = {})
#     %interpolate_16 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_5,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_11 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_5, %interpolate_16), kwargs = {})
#     %interpolate_17 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_11,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_7 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_17, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_0_res_blocks_2_convolution2 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.2.convolution2](args = (%getitem_7,), kwargs = {})
#     %model_res_nets_0_res_blocks_2_batch_norm2 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.2.batch_norm2](args = (%model_res_nets_0_res_blocks_2_convolution2,), kwargs = {})
#     %interpolate_18 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_0_res_blocks_2_gating2_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.2.gating2.transformer.channel_transform](args = (%interpolate_18,), kwargs = {})
#     %model_res_nets_0_res_blocks_2_gating2_gate_weights : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.2.gating2.gate_weights](args = (%model_res_nets_0_res_blocks_2_gating2_transformer_channel_transform,), kwargs = {})
#     %mul_12 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_0_res_blocks_2_gating2_gate_weights), kwargs = {})
#     %sigmoid_6 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_12,), kwargs = {})
#     %unsqueeze_6 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_0_res_blocks_2_batch_norm2, 2), kwargs = {})
#     %interpolate_19 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_6,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_13 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_6, %interpolate_19), kwargs = {})
#     %interpolate_20 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_13,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_8 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_20, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %add_2 : [num_users=2] = call_function[target=operator.add](args = (%add_1, %getitem_8), kwargs = {})
#     %model_res_nets_0_res_blocks_3_convolution1 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.3.convolution1](args = (%add_2,), kwargs = {})
#     %model_res_nets_0_res_blocks_3_batch_norm1 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.3.batch_norm1](args = (%model_res_nets_0_res_blocks_3_convolution1,), kwargs = {})
#     %interpolate_21 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_0_res_blocks_3_gating1_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.3.gating1.transformer.channel_transform](args = (%interpolate_21,), kwargs = {})
#     %model_res_nets_0_res_blocks_3_gating1_gate_weights : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.3.gating1.gate_weights](args = (%model_res_nets_0_res_blocks_3_gating1_transformer_channel_transform,), kwargs = {})
#     %mul_14 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_0_res_blocks_3_gating1_gate_weights), kwargs = {})
#     %sigmoid_7 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_14,), kwargs = {})
#     %unsqueeze_7 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_0_res_blocks_3_batch_norm1, 2), kwargs = {})
#     %interpolate_22 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_7,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_15 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_7, %interpolate_22), kwargs = {})
#     %interpolate_23 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_15,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_9 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_23, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_0_res_blocks_3_convolution2 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.3.convolution2](args = (%getitem_9,), kwargs = {})
#     %model_res_nets_0_res_blocks_3_batch_norm2 : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.3.batch_norm2](args = (%model_res_nets_0_res_blocks_3_convolution2,), kwargs = {})
#     %interpolate_24 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_0_res_blocks_3_gating2_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.3.gating2.transformer.channel_transform](args = (%interpolate_24,), kwargs = {})
#     %model_res_nets_0_res_blocks_3_gating2_gate_weights : [num_users=1] = call_module[target=model.res_nets.0.res_blocks.3.gating2.gate_weights](args = (%model_res_nets_0_res_blocks_3_gating2_transformer_channel_transform,), kwargs = {})
#     %mul_16 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_0_res_blocks_3_gating2_gate_weights), kwargs = {})
#     %sigmoid_8 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_16,), kwargs = {})
#     %unsqueeze_8 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_0_res_blocks_3_batch_norm2, 2), kwargs = {})
#     %interpolate_25 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_8,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_17 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_8, %interpolate_25), kwargs = {})
#     %interpolate_26 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_17,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_10 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_26, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %add_3 : [num_users=1] = call_function[target=operator.add](args = (%add_2, %getitem_10), kwargs = {})
#     %model_encoder_0_convolution : [num_users=1] = call_module[target=model.encoder.0.convolution](args = (%model_lift_convolution,), kwargs = {})
#     %model_encoder_0_batch_norm : [num_users=1] = call_module[target=model.encoder.0.batch_norm](args = (%model_encoder_0_convolution,), kwargs = {})
#     %interpolate_27 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_encoder_0_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.encoder.0.gating.transformer.channel_transform](args = (%interpolate_27,), kwargs = {})
#     %model_encoder_0_gating_gate_weights : [num_users=1] = call_module[target=model.encoder.0.gating.gate_weights](args = (%model_encoder_0_gating_transformer_channel_transform,), kwargs = {})
#     %mul_18 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_encoder_0_gating_gate_weights), kwargs = {})
#     %sigmoid_9 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_18,), kwargs = {})
#     %unsqueeze_9 : [num_users=1] = call_method[target=unsqueeze](args = (%model_encoder_0_batch_norm, 2), kwargs = {})
#     %interpolate_28 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_9,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_19 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_9, %interpolate_28), kwargs = {})
#     %interpolate_29 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_19,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_11 : [num_users=3] = call_function[target=operator.getitem](args = (%interpolate_29, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_1_res_blocks_0_convolution1 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.0.convolution1](args = (%getitem_11,), kwargs = {})
#     %model_res_nets_1_res_blocks_0_batch_norm1 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.0.batch_norm1](args = (%model_res_nets_1_res_blocks_0_convolution1,), kwargs = {})
#     %interpolate_30 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_1_res_blocks_0_gating1_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.0.gating1.transformer.channel_transform](args = (%interpolate_30,), kwargs = {})
#     %model_res_nets_1_res_blocks_0_gating1_gate_weights : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.0.gating1.gate_weights](args = (%model_res_nets_1_res_blocks_0_gating1_transformer_channel_transform,), kwargs = {})
#     %mul_20 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_1_res_blocks_0_gating1_gate_weights), kwargs = {})
#     %sigmoid_10 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_20,), kwargs = {})
#     %unsqueeze_10 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_1_res_blocks_0_batch_norm1, 2), kwargs = {})
#     %interpolate_31 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_10,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_21 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_10, %interpolate_31), kwargs = {})
#     %interpolate_32 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_21,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_12 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_32, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_1_res_blocks_0_convolution2 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.0.convolution2](args = (%getitem_12,), kwargs = {})
#     %model_res_nets_1_res_blocks_0_batch_norm2 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.0.batch_norm2](args = (%model_res_nets_1_res_blocks_0_convolution2,), kwargs = {})
#     %interpolate_33 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_1_res_blocks_0_gating2_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.0.gating2.transformer.channel_transform](args = (%interpolate_33,), kwargs = {})
#     %model_res_nets_1_res_blocks_0_gating2_gate_weights : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.0.gating2.gate_weights](args = (%model_res_nets_1_res_blocks_0_gating2_transformer_channel_transform,), kwargs = {})
#     %mul_22 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_1_res_blocks_0_gating2_gate_weights), kwargs = {})
#     %sigmoid_11 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_22,), kwargs = {})
#     %unsqueeze_11 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_1_res_blocks_0_batch_norm2, 2), kwargs = {})
#     %interpolate_34 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_11,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_23 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_11, %interpolate_34), kwargs = {})
#     %interpolate_35 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_23,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_13 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_35, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %add_4 : [num_users=2] = call_function[target=operator.add](args = (%getitem_11, %getitem_13), kwargs = {})
#     %model_res_nets_1_res_blocks_1_convolution1 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.1.convolution1](args = (%add_4,), kwargs = {})
#     %model_res_nets_1_res_blocks_1_batch_norm1 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.1.batch_norm1](args = (%model_res_nets_1_res_blocks_1_convolution1,), kwargs = {})
#     %interpolate_36 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_1_res_blocks_1_gating1_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.1.gating1.transformer.channel_transform](args = (%interpolate_36,), kwargs = {})
#     %model_res_nets_1_res_blocks_1_gating1_gate_weights : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.1.gating1.gate_weights](args = (%model_res_nets_1_res_blocks_1_gating1_transformer_channel_transform,), kwargs = {})
#     %mul_24 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_1_res_blocks_1_gating1_gate_weights), kwargs = {})
#     %sigmoid_12 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_24,), kwargs = {})
#     %unsqueeze_12 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_1_res_blocks_1_batch_norm1, 2), kwargs = {})
#     %interpolate_37 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_12,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_25 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_12, %interpolate_37), kwargs = {})
#     %interpolate_38 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_25,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_14 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_38, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_1_res_blocks_1_convolution2 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.1.convolution2](args = (%getitem_14,), kwargs = {})
#     %model_res_nets_1_res_blocks_1_batch_norm2 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.1.batch_norm2](args = (%model_res_nets_1_res_blocks_1_convolution2,), kwargs = {})
#     %interpolate_39 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_1_res_blocks_1_gating2_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.1.gating2.transformer.channel_transform](args = (%interpolate_39,), kwargs = {})
#     %model_res_nets_1_res_blocks_1_gating2_gate_weights : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.1.gating2.gate_weights](args = (%model_res_nets_1_res_blocks_1_gating2_transformer_channel_transform,), kwargs = {})
#     %mul_26 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_1_res_blocks_1_gating2_gate_weights), kwargs = {})
#     %sigmoid_13 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_26,), kwargs = {})
#     %unsqueeze_13 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_1_res_blocks_1_batch_norm2, 2), kwargs = {})
#     %interpolate_40 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_13,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_27 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_13, %interpolate_40), kwargs = {})
#     %interpolate_41 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_27,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_15 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_41, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %add_5 : [num_users=2] = call_function[target=operator.add](args = (%add_4, %getitem_15), kwargs = {})
#     %model_res_nets_1_res_blocks_2_convolution1 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.2.convolution1](args = (%add_5,), kwargs = {})
#     %model_res_nets_1_res_blocks_2_batch_norm1 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.2.batch_norm1](args = (%model_res_nets_1_res_blocks_2_convolution1,), kwargs = {})
#     %interpolate_42 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_1_res_blocks_2_gating1_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.2.gating1.transformer.channel_transform](args = (%interpolate_42,), kwargs = {})
#     %model_res_nets_1_res_blocks_2_gating1_gate_weights : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.2.gating1.gate_weights](args = (%model_res_nets_1_res_blocks_2_gating1_transformer_channel_transform,), kwargs = {})
#     %mul_28 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_1_res_blocks_2_gating1_gate_weights), kwargs = {})
#     %sigmoid_14 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_28,), kwargs = {})
#     %unsqueeze_14 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_1_res_blocks_2_batch_norm1, 2), kwargs = {})
#     %interpolate_43 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_14,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_29 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_14, %interpolate_43), kwargs = {})
#     %interpolate_44 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_29,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_16 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_44, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_1_res_blocks_2_convolution2 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.2.convolution2](args = (%getitem_16,), kwargs = {})
#     %model_res_nets_1_res_blocks_2_batch_norm2 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.2.batch_norm2](args = (%model_res_nets_1_res_blocks_2_convolution2,), kwargs = {})
#     %interpolate_45 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_1_res_blocks_2_gating2_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.2.gating2.transformer.channel_transform](args = (%interpolate_45,), kwargs = {})
#     %model_res_nets_1_res_blocks_2_gating2_gate_weights : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.2.gating2.gate_weights](args = (%model_res_nets_1_res_blocks_2_gating2_transformer_channel_transform,), kwargs = {})
#     %mul_30 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_1_res_blocks_2_gating2_gate_weights), kwargs = {})
#     %sigmoid_15 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_30,), kwargs = {})
#     %unsqueeze_15 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_1_res_blocks_2_batch_norm2, 2), kwargs = {})
#     %interpolate_46 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_15,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_31 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_15, %interpolate_46), kwargs = {})
#     %interpolate_47 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_31,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_17 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_47, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %add_6 : [num_users=2] = call_function[target=operator.add](args = (%add_5, %getitem_17), kwargs = {})
#     %model_res_nets_1_res_blocks_3_convolution1 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.3.convolution1](args = (%add_6,), kwargs = {})
#     %model_res_nets_1_res_blocks_3_batch_norm1 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.3.batch_norm1](args = (%model_res_nets_1_res_blocks_3_convolution1,), kwargs = {})
#     %interpolate_48 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_1_res_blocks_3_gating1_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.3.gating1.transformer.channel_transform](args = (%interpolate_48,), kwargs = {})
#     %model_res_nets_1_res_blocks_3_gating1_gate_weights : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.3.gating1.gate_weights](args = (%model_res_nets_1_res_blocks_3_gating1_transformer_channel_transform,), kwargs = {})
#     %mul_32 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_1_res_blocks_3_gating1_gate_weights), kwargs = {})
#     %sigmoid_16 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_32,), kwargs = {})
#     %unsqueeze_16 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_1_res_blocks_3_batch_norm1, 2), kwargs = {})
#     %interpolate_49 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_16,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_33 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_16, %interpolate_49), kwargs = {})
#     %interpolate_50 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_33,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_18 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_50, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_1_res_blocks_3_convolution2 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.3.convolution2](args = (%getitem_18,), kwargs = {})
#     %model_res_nets_1_res_blocks_3_batch_norm2 : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.3.batch_norm2](args = (%model_res_nets_1_res_blocks_3_convolution2,), kwargs = {})
#     %interpolate_51 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_1_res_blocks_3_gating2_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.3.gating2.transformer.channel_transform](args = (%interpolate_51,), kwargs = {})
#     %model_res_nets_1_res_blocks_3_gating2_gate_weights : [num_users=1] = call_module[target=model.res_nets.1.res_blocks.3.gating2.gate_weights](args = (%model_res_nets_1_res_blocks_3_gating2_transformer_channel_transform,), kwargs = {})
#     %mul_34 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_1_res_blocks_3_gating2_gate_weights), kwargs = {})
#     %sigmoid_17 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_34,), kwargs = {})
#     %unsqueeze_17 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_1_res_blocks_3_batch_norm2, 2), kwargs = {})
#     %interpolate_52 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_17,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_35 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_17, %interpolate_52), kwargs = {})
#     %interpolate_53 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_35,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_19 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_53, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %add_7 : [num_users=1] = call_function[target=operator.add](args = (%add_6, %getitem_19), kwargs = {})
#     %model_encoder_1_convolution : [num_users=1] = call_module[target=model.encoder.1.convolution](args = (%getitem_11,), kwargs = {})
#     %model_encoder_1_batch_norm : [num_users=1] = call_module[target=model.encoder.1.batch_norm](args = (%model_encoder_1_convolution,), kwargs = {})
#     %interpolate_54 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 32, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_encoder_1_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.encoder.1.gating.transformer.channel_transform](args = (%interpolate_54,), kwargs = {})
#     %model_encoder_1_gating_gate_weights : [num_users=1] = call_module[target=model.encoder.1.gating.gate_weights](args = (%model_encoder_1_gating_transformer_channel_transform,), kwargs = {})
#     %mul_36 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_encoder_1_gating_gate_weights), kwargs = {})
#     %sigmoid_18 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_36,), kwargs = {})
#     %unsqueeze_18 : [num_users=1] = call_method[target=unsqueeze](args = (%model_encoder_1_batch_norm, 2), kwargs = {})
#     %interpolate_55 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_18,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_37 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_18, %interpolate_55), kwargs = {})
#     %interpolate_56 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_37,), kwargs = {size: (1, 32), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_20 : [num_users=3] = call_function[target=operator.getitem](args = (%interpolate_56, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_2_res_blocks_0_convolution1 : [num_users=1] = call_module[target=model.res_nets.2.res_blocks.0.convolution1](args = (%getitem_20,), kwargs = {})
#     %model_res_nets_2_res_blocks_0_batch_norm1 : [num_users=1] = call_module[target=model.res_nets.2.res_blocks.0.batch_norm1](args = (%model_res_nets_2_res_blocks_0_convolution1,), kwargs = {})
#     %interpolate_57 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 32, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_2_res_blocks_0_gating1_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.2.res_blocks.0.gating1.transformer.channel_transform](args = (%interpolate_57,), kwargs = {})
#     %model_res_nets_2_res_blocks_0_gating1_gate_weights : [num_users=1] = call_module[target=model.res_nets.2.res_blocks.0.gating1.gate_weights](args = (%model_res_nets_2_res_blocks_0_gating1_transformer_channel_transform,), kwargs = {})
#     %mul_38 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_2_res_blocks_0_gating1_gate_weights), kwargs = {})
#     %sigmoid_19 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_38,), kwargs = {})
#     %unsqueeze_19 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_2_res_blocks_0_batch_norm1, 2), kwargs = {})
#     %interpolate_58 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_19,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_39 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_19, %interpolate_58), kwargs = {})
#     %interpolate_59 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_39,), kwargs = {size: (1, 32), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_21 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_59, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_res_nets_2_res_blocks_0_convolution2 : [num_users=1] = call_module[target=model.res_nets.2.res_blocks.0.convolution2](args = (%getitem_21,), kwargs = {})
#     %model_res_nets_2_res_blocks_0_batch_norm2 : [num_users=1] = call_module[target=model.res_nets.2.res_blocks.0.batch_norm2](args = (%model_res_nets_2_res_blocks_0_convolution2,), kwargs = {})
#     %interpolate_60 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 32, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_res_nets_2_res_blocks_0_gating2_transformer_channel_transform : [num_users=1] = call_module[target=model.res_nets.2.res_blocks.0.gating2.transformer.channel_transform](args = (%interpolate_60,), kwargs = {})
#     %model_res_nets_2_res_blocks_0_gating2_gate_weights : [num_users=1] = call_module[target=model.res_nets.2.res_blocks.0.gating2.gate_weights](args = (%model_res_nets_2_res_blocks_0_gating2_transformer_channel_transform,), kwargs = {})
#     %mul_40 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_res_nets_2_res_blocks_0_gating2_gate_weights), kwargs = {})
#     %sigmoid_20 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_40,), kwargs = {})
#     %unsqueeze_20 : [num_users=1] = call_method[target=unsqueeze](args = (%model_res_nets_2_res_blocks_0_batch_norm2, 2), kwargs = {})
#     %interpolate_61 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_20,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_41 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_20, %interpolate_61), kwargs = {})
#     %interpolate_62 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_41,), kwargs = {size: (1, 32), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_22 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_62, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %add_8 : [num_users=2] = call_function[target=operator.add](args = (%getitem_20, %getitem_22), kwargs = {})
#     %model_res_nets_2_res_blocks_1_convolution1 : [num_users=1] = call_module[target=model.res_nets.2.res_blocks.1.convolution1](args = (%add_8,), kwargs = {})
# ...
#     %mul_95 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_47, %interpolate_142), kwargs = {})
#     %interpolate_143 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_95,), kwargs = {size: (1, 16), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_49 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_143, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %cat_1 : [num_users=1] = call_function[target=torch.cat](args = ((%getitem_48, %getitem_49), 1), kwargs = {})
#     %model_decoder_1_convolution : [num_users=1] = call_module[target=model.decoder.1.convolution](args = (%cat_1,), kwargs = {})
#     %model_decoder_1_batch_norm : [num_users=1] = call_module[target=model.decoder.1.batch_norm](args = (%model_decoder_1_convolution,), kwargs = {})
#     %interpolate_144 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 32, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_decoder_1_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.decoder.1.gating.transformer.channel_transform](args = (%interpolate_144,), kwargs = {})
#     %model_decoder_1_gating_gate_weights : [num_users=1] = call_module[target=model.decoder.1.gating.gate_weights](args = (%model_decoder_1_gating_transformer_channel_transform,), kwargs = {})
#     %mul_96 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_decoder_1_gating_gate_weights), kwargs = {})
#     %sigmoid_48 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_96,), kwargs = {})
#     %unsqueeze_48 : [num_users=1] = call_method[target=unsqueeze](args = (%model_decoder_1_batch_norm, 2), kwargs = {})
#     %interpolate_145 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_48,), kwargs = {size: (1, 32), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_97 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_48, %interpolate_145), kwargs = {})
#     %interpolate_146 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_97,), kwargs = {size: (1, 32), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_50 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_146, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_ed_expansion_2_convolution : [num_users=1] = call_module[target=model.ED_expansion.2.convolution](args = (%add_11,), kwargs = {})
#     %model_ed_expansion_2_batch_norm : [num_users=1] = call_module[target=model.ED_expansion.2.batch_norm](args = (%model_ed_expansion_2_convolution,), kwargs = {})
#     %interpolate_147 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 32, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_ed_expansion_2_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.ED_expansion.2.gating.transformer.channel_transform](args = (%interpolate_147,), kwargs = {})
#     %model_ed_expansion_2_gating_gate_weights : [num_users=1] = call_module[target=model.ED_expansion.2.gating.gate_weights](args = (%model_ed_expansion_2_gating_transformer_channel_transform,), kwargs = {})
#     %mul_98 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_ed_expansion_2_gating_gate_weights), kwargs = {})
#     %sigmoid_49 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_98,), kwargs = {})
#     %unsqueeze_49 : [num_users=1] = call_method[target=unsqueeze](args = (%model_ed_expansion_2_batch_norm, 2), kwargs = {})
#     %interpolate_148 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_49,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_99 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_49, %interpolate_148), kwargs = {})
#     %interpolate_149 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_99,), kwargs = {size: (1, 32), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_51 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_149, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %cat_2 : [num_users=1] = call_function[target=torch.cat](args = ((%getitem_50, %getitem_51), 1), kwargs = {})
#     %model_decoder_2_convolution : [num_users=1] = call_module[target=model.decoder.2.convolution](args = (%cat_2,), kwargs = {})
#     %model_decoder_2_batch_norm : [num_users=1] = call_module[target=model.decoder.2.batch_norm](args = (%model_decoder_2_convolution,), kwargs = {})
#     %interpolate_150 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_decoder_2_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.decoder.2.gating.transformer.channel_transform](args = (%interpolate_150,), kwargs = {})
#     %model_decoder_2_gating_gate_weights : [num_users=1] = call_module[target=model.decoder.2.gating.gate_weights](args = (%model_decoder_2_gating_transformer_channel_transform,), kwargs = {})
#     %mul_100 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_decoder_2_gating_gate_weights), kwargs = {})
#     %sigmoid_50 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_100,), kwargs = {})
#     %unsqueeze_50 : [num_users=1] = call_method[target=unsqueeze](args = (%model_decoder_2_batch_norm, 2), kwargs = {})
#     %interpolate_151 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_50,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_101 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_50, %interpolate_151), kwargs = {})
#     %interpolate_152 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_101,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_52 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_152, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_ed_expansion_1_convolution : [num_users=1] = call_module[target=model.ED_expansion.1.convolution](args = (%add_7,), kwargs = {})
#     %model_ed_expansion_1_batch_norm : [num_users=1] = call_module[target=model.ED_expansion.1.batch_norm](args = (%model_ed_expansion_1_convolution,), kwargs = {})
#     %interpolate_153 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 64, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_ed_expansion_1_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.ED_expansion.1.gating.transformer.channel_transform](args = (%interpolate_153,), kwargs = {})
#     %model_ed_expansion_1_gating_gate_weights : [num_users=1] = call_module[target=model.ED_expansion.1.gating.gate_weights](args = (%model_ed_expansion_1_gating_transformer_channel_transform,), kwargs = {})
#     %mul_102 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_ed_expansion_1_gating_gate_weights), kwargs = {})
#     %sigmoid_51 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_102,), kwargs = {})
#     %unsqueeze_51 : [num_users=1] = call_method[target=unsqueeze](args = (%model_ed_expansion_1_batch_norm, 2), kwargs = {})
#     %interpolate_154 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_51,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_103 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_51, %interpolate_154), kwargs = {})
#     %interpolate_155 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_103,), kwargs = {size: (1, 64), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_53 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_155, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %cat_3 : [num_users=1] = call_function[target=torch.cat](args = ((%getitem_52, %getitem_53), 1), kwargs = {})
#     %model_decoder_3_convolution : [num_users=1] = call_module[target=model.decoder.3.convolution](args = (%cat_3,), kwargs = {})
#     %model_decoder_3_batch_norm : [num_users=1] = call_module[target=model.decoder.3.batch_norm](args = (%model_decoder_3_convolution,), kwargs = {})
#     %interpolate_156 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_decoder_3_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.decoder.3.gating.transformer.channel_transform](args = (%interpolate_156,), kwargs = {})
#     %model_decoder_3_gating_gate_weights : [num_users=1] = call_module[target=model.decoder.3.gating.gate_weights](args = (%model_decoder_3_gating_transformer_channel_transform,), kwargs = {})
#     %mul_104 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_decoder_3_gating_gate_weights), kwargs = {})
#     %sigmoid_52 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_104,), kwargs = {})
#     %unsqueeze_52 : [num_users=1] = call_method[target=unsqueeze](args = (%model_decoder_3_batch_norm, 2), kwargs = {})
#     %interpolate_157 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_52,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_105 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_52, %interpolate_157), kwargs = {})
#     %interpolate_158 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_105,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_54 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_158, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_ed_expansion_0_convolution : [num_users=1] = call_module[target=model.ED_expansion.0.convolution](args = (%add_3,), kwargs = {})
#     %model_ed_expansion_0_batch_norm : [num_users=1] = call_module[target=model.ED_expansion.0.batch_norm](args = (%model_ed_expansion_0_convolution,), kwargs = {})
#     %interpolate_159 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_ed_expansion_0_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.ED_expansion.0.gating.transformer.channel_transform](args = (%interpolate_159,), kwargs = {})
#     %model_ed_expansion_0_gating_gate_weights : [num_users=1] = call_module[target=model.ED_expansion.0.gating.gate_weights](args = (%model_ed_expansion_0_gating_transformer_channel_transform,), kwargs = {})
#     %mul_106 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_ed_expansion_0_gating_gate_weights), kwargs = {})
#     %sigmoid_53 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_106,), kwargs = {})
#     %unsqueeze_53 : [num_users=1] = call_method[target=unsqueeze](args = (%model_ed_expansion_0_batch_norm, 2), kwargs = {})
#     %interpolate_160 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_53,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_107 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_53, %interpolate_160), kwargs = {})
#     %interpolate_161 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_107,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_55 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_161, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %cat_4 : [num_users=1] = call_function[target=torch.cat](args = ((%getitem_54, %getitem_55), 1), kwargs = {})
#     %model_project_inter_cnoblock_convolution : [num_users=1] = call_module[target=model.project.inter_CNOBlock.convolution](args = (%cat_4,), kwargs = {})
#     %model_project_inter_cnoblock_batch_norm : [num_users=1] = call_module[target=model.project.inter_CNOBlock.batch_norm](args = (%model_project_inter_cnoblock_convolution,), kwargs = {})
#     %interpolate_162 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%clone,), kwargs = {size: 128, scale_factor: None, mode: linear, align_corners: False, recompute_scale_factor: None, antialias: False})
#     %model_project_inter_cnoblock_gating_transformer_channel_transform : [num_users=1] = call_module[target=model.project.inter_CNOBlock.gating.transformer.channel_transform](args = (%interpolate_162,), kwargs = {})
#     %model_project_inter_cnoblock_gating_gate_weights : [num_users=1] = call_module[target=model.project.inter_CNOBlock.gating.gate_weights](args = (%model_project_inter_cnoblock_gating_transformer_channel_transform,), kwargs = {})
#     %mul_108 : [num_users=1] = call_function[target=operator.mul](args = (1.0, %model_project_inter_cnoblock_gating_gate_weights), kwargs = {})
#     %sigmoid_54 : [num_users=1] = call_function[target=torch.sigmoid](args = (%mul_108,), kwargs = {})
#     %unsqueeze_54 : [num_users=1] = call_method[target=unsqueeze](args = (%model_project_inter_cnoblock_batch_norm, 2), kwargs = {})
#     %interpolate_163 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%unsqueeze_54,), kwargs = {size: (1, 256), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %mul_109 : [num_users=1] = call_function[target=operator.mul](args = (%sigmoid_54, %interpolate_163), kwargs = {})
#     %interpolate_164 : [num_users=1] = call_function[target=torch.nn.functional.interpolate](args = (%mul_109,), kwargs = {size: (1, 128), scale_factor: None, mode: bicubic, align_corners: None, recompute_scale_factor: None, antialias: True})
#     %getitem_56 : [num_users=1] = call_function[target=operator.getitem](args = (%interpolate_164, (slice(None, None, None), slice(None, None, None), 0)), kwargs = {})
#     %model_project_convolution : [num_users=1] = call_module[target=model.project.convolution](args = (%getitem_56,), kwargs = {})
#     %permute_1 : [num_users=1] = call_method[target=permute](args = (%model_project_convolution, 0, 2, 1), kwargs = {})
#     %unsqueeze_55 : [num_users=1] = call_method[target=unsqueeze](args = (%permute_1, -2), kwargs = {})
#     return unsqueeze_55

# %%
pip install torchviz
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.3-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from torchviz) (2.6.0+cu124)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from torchviz) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->torchviz)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->torchviz)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->torchviz)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->torchviz)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->torchviz)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->torchviz)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->torchviz)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->torchviz)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->torchviz)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->torchviz)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->torchviz) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->torchviz) (3.0.2)
# Downloading torchviz-0.0.3-py3-none-any.whl (5.7 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 34.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 20.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchviz
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torchviz-0.0.3

# %%
class FNODatasetSingle(Dataset):
    def __init__(
        self,
        filename,
        initial_step=10,
        saved_folder="../data/",
        reduced_resolution=1,
        reduced_resolution_t=1,
        reduced_batch=1,
        if_test=False,
        test_ratio=0.1,
        num_samples_max=-1,
    ):
        """

        :param filename: filename that contains the dataset
        :type filename: STR
        :param filenum: array containing indices of filename included in the dataset
        :type filenum: ARRAY
        :param initial_step: time steps taken as initial condition, defaults to 10
        :type initial_step: INT, optional

        """

        # Define path to files
        root_path = Path(Path(saved_folder).resolve()) / filename
        if filename[-2:] != "h5":
            # print(".HDF5 file extension is assumed hereafter")

            with h5py.File(root_path, "r") as f:
                keys = list(f.keys())
                keys.sort()
                if "tensor" not in keys:
                    _data = np.array(
                        f["density"], dtype=np.float32
                    )  # batch, time, x,...
                    idx_cfd = _data.shape
                    if len(idx_cfd) == 3:  # 1D
                        self.data = np.zeros(
                            [
                                idx_cfd[0] // reduced_batch,
                                idx_cfd[2] // reduced_resolution,
                                mt.ceil(idx_cfd[1] / reduced_resolution_t),
                                3,
                            ],
                            dtype=np.float32,
                        )
                        # density
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data[:, :, :], (0, 2, 1))
                        self.data[..., 0] = _data  # batch, x, t, ch
                        # pressure
                        _data = np.array(
                            f["pressure"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data[:, :, :], (0, 2, 1))
                        self.data[..., 1] = _data  # batch, x, t, ch
                        # Vx
                        _data = np.array(
                            f["Vx"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data[:, :, :], (0, 2, 1))
                        self.data[..., 2] = _data  # batch, x, t, ch

                        self.grid = np.array(f["x-coordinate"], dtype=np.float32)
                        self.grid = torch.tensor(
                            self.grid[::reduced_resolution], dtype=torch.float
                        ).unsqueeze(-1)
                        # print(self.data.shape)
                    if len(idx_cfd) == 4:  # 2D
                        self.data = np.zeros(
                            [
                                idx_cfd[0] // reduced_batch,
                                idx_cfd[2] // reduced_resolution,
                                idx_cfd[3] // reduced_resolution,
                                mt.ceil(idx_cfd[1] / reduced_resolution_t),
                                4,
                            ],
                            dtype=np.float32,
                        )
                        # density
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data, (0, 2, 3, 1))
                        self.data[..., 0] = _data  # batch, x, t, ch
                        # pressure
                        _data = np.array(
                            f["pressure"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data, (0, 2, 3, 1))
                        self.data[..., 1] = _data  # batch, x, t, ch
                        # Vx
                        _data = np.array(
                            f["Vx"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data, (0, 2, 3, 1))
                        self.data[..., 2] = _data  # batch, x, t, ch
                        # Vy
                        _data = np.array(
                            f["Vy"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data, (0, 2, 3, 1))
                        self.data[..., 3] = _data  # batch, x, t, ch

                        x = np.array(f["x-coordinate"], dtype=np.float32)
                        y = np.array(f["y-coordinate"], dtype=np.float32)
                        x = torch.tensor(x, dtype=torch.float)
                        y = torch.tensor(y, dtype=torch.float)
                        X, Y = torch.meshgrid(x, y, indexing="ij")
                        self.grid = torch.stack((X, Y), axis=-1)[
                            ::reduced_resolution, ::reduced_resolution
                        ]

                    if len(idx_cfd) == 5:  # 3D
                        self.data = np.zeros(
                            [
                                idx_cfd[0] // reduced_batch,
                                idx_cfd[2] // reduced_resolution,
                                idx_cfd[3] // reduced_resolution,
                                idx_cfd[4] // reduced_resolution,
                                mt.ceil(idx_cfd[1] / reduced_resolution_t),
                                5,
                            ],
                            dtype=np.float32,
                        )
                        # density
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data, (0, 2, 3, 4, 1))
                        self.data[..., 0] = _data  # batch, x, t, ch
                        # pressure
                        _data = np.array(
                            f["pressure"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data, (0, 2, 3, 4, 1))
                        self.data[..., 1] = _data  # batch, x, t, ch
                        # Vx
                        _data = np.array(
                            f["Vx"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data, (0, 2, 3, 4, 1))
                        self.data[..., 2] = _data  # batch, x, t, ch
                        # Vy
                        _data = np.array(
                            f["Vy"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data, (0, 2, 3, 4, 1))
                        self.data[..., 3] = _data  # batch, x, t, ch
                        # Vz
                        _data = np.array(
                            f["Vz"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data, (0, 2, 3, 4, 1))
                        self.data[..., 4] = _data  # batch, x, t, ch

                        x = np.array(f["x-coordinate"], dtype=np.float32)
                        y = np.array(f["y-coordinate"], dtype=np.float32)
                        z = np.array(f["z-coordinate"], dtype=np.float32)
                        x = torch.tensor(x, dtype=torch.float)
                        y = torch.tensor(y, dtype=torch.float)
                        z = torch.tensor(z, dtype=torch.float)
                        X, Y, Z = torch.meshgrid(x, y, z, indexing="ij")
                        self.grid = torch.stack((X, Y, Z), axis=-1)[
                            ::reduced_resolution,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]

                else:  # scalar equations
                    ## data dim = [t, x1, ..., xd, v]
                    _data = np.array(
                        f["tensor"], dtype=np.float32
                    )  # batch, time, x,...
                    if len(_data.shape) == 3:  # 1D
                        _data = _data[
                            ::reduced_batch,
                            ::reduced_resolution_t,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data[:, :, :], (0, 2, 1))
                        self.data = _data[:, :, :, None]  # batch, x, t, ch

                        self.grid = np.array(f["x-coordinate"], dtype=np.float32)
                        self.grid = torch.tensor(
                            self.grid[::reduced_resolution], dtype=torch.float
                        ).unsqueeze(-1)
                    if len(_data.shape) == 4:  # 2D Darcy flow
                        # u: label
                        _data = _data[
                            ::reduced_batch,
                            :,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data[:, :, :, :], (0, 2, 3, 1))
                        # if _data.shape[-1]==1:  # if nt==1
                        #    _data = np.tile(_data, (1, 1, 1, 2))
                        self.data = _data
                        # nu: input
                        _data = np.array(
                            f["nu"], dtype=np.float32
                        )  # batch, time, x,...
                        _data = _data[
                            ::reduced_batch,
                            None,
                            ::reduced_resolution,
                            ::reduced_resolution,
                        ]
                        ## convert to [x1, ..., xd, t, v]
                        _data = np.transpose(_data[:, :, :, :], (0, 2, 3, 1))
                        self.data = np.concatenate([_data, self.data], axis=-1)
                        self.data = self.data[:, :, :, :, None]  # batch, x, y, t, ch

                        x = np.array(f["x-coordinate"], dtype=np.float32)
                        y = np.array(f["y-coordinate"], dtype=np.float32)
                        x = torch.tensor(x, dtype=torch.float)
                        y = torch.tensor(y, dtype=torch.float)
                        X, Y = torch.meshgrid(x, y, indexing="ij")
                        self.grid = torch.stack((X, Y), axis=-1)[
                            ::reduced_resolution, ::reduced_resolution
                        ]

        elif filename[-2:] == "h5":  # SWE-2D (RDB)
            # print(".H5 file extension is assumed hereafter")

            with h5py.File(root_path, "r") as f:
                keys = list(f.keys())
                keys.sort()

                data_arrays = [
                    np.array(f[key]["data"], dtype=np.float32) for key in keys
                ]
                _data = torch.from_numpy(
                    np.stack(data_arrays, axis=0)
                )  # [batch, nt, nx, ny, nc]
                _data = _data[
                    ::reduced_batch,
                    ::reduced_resolution_t,
                    ::reduced_resolution,
                    ::reduced_resolution,
                    ...,
                ]
                _data = torch.permute(_data, (0, 2, 3, 1, 4))  # [batch, nx, ny, nt, nc]
                gridx, gridy = (
                    np.array(f["0023"]["grid"]["x"], dtype=np.float32),
                    np.array(f["0023"]["grid"]["y"], dtype=np.float32),
                )
                mgridX, mgridY = np.meshgrid(gridx, gridy, indexing="ij")
                _grid = torch.stack(
                    (torch.from_numpy(mgridX), torch.from_numpy(mgridY)), axis=-1
                )
                _grid = _grid[::reduced_resolution, ::reduced_resolution, ...]
                _tsteps_t = torch.from_numpy(
                    np.array(f["0023"]["grid"]["t"], dtype=np.float32)
                )

                tsteps_t = _tsteps_t[::reduced_resolution_t]
                self.data = _data
                self.grid = _grid
                self.tsteps_t = tsteps_t

        if num_samples_max > 0:
            num_samples_max = min(num_samples_max, self.data.shape[0])
        else:
            num_samples_max = self.data.shape[0]

        test_idx = int(num_samples_max * test_ratio)
        if if_test:
            self.data = self.data[:test_idx]
        else:
            self.data = self.data[test_idx:num_samples_max]

        # Time steps used as initial conditions
        self.initial_step = initial_step

        self.data = self.data if torch.is_tensor(self.data) else torch.tensor(self.data)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx, ..., : self.initial_step, :], self.data[idx], self.grid

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logger = logging.getLogger(__name__)

# %%
filename = "1D_Advection_Sols_beta0.1_reduced.hdf5"
base_path = "/content/drive/MyDrive/"

# Training settings
if_training = True
continue_training = False
num_workers = 0
batch_size = 500
initial_step = 10
t_train = 200
epochs = 500
learning_rate = 1e-3
scheduler_step = 100
scheduler_gamma = 0.5
model_update = 1

# %%
num_channels = 1
size = 128  # Spatial grid size (important for CNO)

# New CNO specific parameters (replacing FNO parameters)
N_layers = 4
N_res = 4
N_res_neck = 4
channel_multiplier = 16

# Dataset preprocessing options
single_file = True
reduced_resolution = 1
reduced_resolution_t = 1
reduced_batch = 1

# Plotting and bounds
plot = False
training_type = "autoregressive"

# %%
model_name = filename[:-5] + "_CNO_500"
model_path = model_name + ".pt"

# %%
model_path
# Out:
# '1D_Advection_Sols_beta0.1_reduced_CNO_500.pt'

# %%
train_data = FNODatasetSingle(
    filename,
    reduced_resolution=reduced_resolution,
    reduced_resolution_t=reduced_resolution_t,
    reduced_batch=reduced_batch,
    initial_step=initial_step,
    saved_folder=base_path,
)

val_data = FNODatasetSingle(
    filename,
    reduced_resolution=reduced_resolution,
    reduced_resolution_t=reduced_resolution_t,
    reduced_batch=reduced_batch,
    initial_step=initial_step,
    if_test=True,
    saved_folder=base_path,
)

# %%
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, num_workers=num_workers, shuffle=False)

# %%
print("NUmber of batches",len(train_loader))
for batch in train_loader:
    print(f"Batch type: {type(batch)}")
    if isinstance(batch, (tuple, list)):
        print("Shapes of elements in batch:")
        for item in batch:
            print(item.shape)
    else:
        print(batch.shape)
    break  # only show the first batch
# Out:
# NUmber of batches 18
# Batch type: <class 'list'>
# Shapes of elements in batch:
# torch.Size([500, 256, 10, 1])
# torch.Size([500, 256, 41, 1])
# torch.Size([500, 256, 1])

# %%
_, _data, _grid = next(iter(val_loader))
t_train = min(t_train, _data.shape[-2])
size = _data.shape[1]

# %%
model = CNO1d(
    num_channels=num_channels,
    width=channel_multiplier,  # Use channel_multiplier as width
    initial_step=initial_step,
    size=size,
    N_layers=N_layers,
    N_res=N_res,
    N_res_neck=N_res_neck,
    channel_multiplier=channel_multiplier,
    use_bn=True
).to(device)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step, gamma=scheduler_gamma)
loss_fn = nn.MSELoss(reduction="mean")
loss_val_min = np.inf
start_epoch = 0

# %%
def metric_func(
    pred, target, if_mean=True, Lx=1.0, Ly=1.0, Lz=1.0, iLow=4, iHigh=12, initial_step=1
):
    """
    code for calculate metrics discussed in the Brain-storming session
    RMSE, normalized RMSE, max error, RMSE at the boundaries, conserved variables, RMSE in Fourier space, temporal sensitivity
    """
    pred, target = pred.to(device), target.to(device)
    # (batch, nx^i..., timesteps, nc)
    # slice out `initial context` timesteps
    pred = pred[..., initial_step:, :]
    target = target[..., initial_step:, :]
    idxs = target.size()
    if len(idxs) == 4:  # 1D
        pred = pred.permute(0, 3, 1, 2)
        target = target.permute(0, 3, 1, 2)

    idxs = target.size()
    nb, nc, nt = idxs[0], idxs[1], idxs[-1]

    # RMSE
    err_mean = torch.sqrt(
        torch.mean(
            (pred.view([nb, nc, -1, nt]) - target.view([nb, nc, -1, nt])) ** 2, dim=2
        )
    )
    err_RMSE = torch.mean(err_mean, axis=0)
    nrm = torch.sqrt(torch.mean(target.view([nb, nc, -1, nt]) ** 2, dim=2))
    err_nRMSE = torch.mean(err_mean / nrm, dim=0)

    err_CSV = torch.sqrt(
        torch.mean(
            (
                torch.sum(pred.view([nb, nc, -1, nt]), dim=2)
                - torch.sum(target.view([nb, nc, -1, nt]), dim=2)
            )
            ** 2,
            dim=0,
        )
    )
    if len(idxs) == 4:
        nx = idxs[2]
        err_CSV /= nx

    # worst case in all the data
    err_Max = torch.max(
        torch.max(
            torch.abs(pred.view([nb, nc, -1, nt]) - target.view([nb, nc, -1, nt])),
            dim=2,
        )[0],
        dim=0,
    )[0]

    if len(idxs) == 4:  # 1D
        err_BD = (pred[:, :, 0, :] - target[:, :, 0, :]) ** 2
        err_BD += (pred[:, :, -1, :] - target[:, :, -1, :]) ** 2
        err_BD = torch.mean(torch.sqrt(err_BD / 2.0), dim=0)

    if len(idxs) == 4:  # 1D
        nx = idxs[2]
        pred_F = torch.fft.rfft(pred, dim=2)
        target_F = torch.fft.rfft(target, dim=2)
        _err_F = (
            torch.sqrt(torch.mean(torch.abs(pred_F - target_F) ** 2, axis=0)) / nx * Lx
        )

    err_F = torch.zeros([nc, 3, nt]).to(device)
    err_F[:, 0] += torch.mean(_err_F[:, :iLow], dim=1)  # low freq
    err_F[:, 1] += torch.mean(_err_F[:, iLow:iHigh], dim=1)  # middle freq
    err_F[:, 2] += torch.mean(_err_F[:, iHigh:], dim=1)  # high freq

    if if_mean:
        return (
            torch.mean(err_RMSE, dim=[0, -1]),
            torch.mean(err_nRMSE, dim=[0, -1]),
            torch.mean(err_CSV, dim=[0, -1]),
            torch.mean(err_Max, dim=[0, -1]),
            torch.mean(err_BD, dim=[0, -1]),
            torch.mean(err_F, dim=[0, -1]),
        )
    return err_RMSE, err_nRMSE, err_CSV, err_Max, err_BD, err_F

# %%
def metrics(
    val_loader,
    model,
    Lx,
    Ly,
    Lz,
    plot,
    channel_plot,
    model_name,
    x_min,
    x_max,
    y_min,
    y_max,
    t_min,
    t_max,
    mode="CNO",  # Changed default to CNO
    initial_step=None,
):
    if mode == "CNO":  # Update to use CNO instead of FNO
        with torch.no_grad():
            itot = 0
            for itot, (xx, yy, grid) in enumerate(val_loader):
                xx = xx.to(device)  # noqa: PLW2901
                yy = yy.to(device)  # noqa: PLW2901
                grid = grid.to(device)  # noqa: PLW2901

                pred = yy[..., :initial_step, :]
                inp_shape = list(xx.shape)
                inp_shape = inp_shape[:-2]
                inp_shape.append(-1)

                for _t in range(initial_step, yy.shape[-2]):
                    inp = xx.reshape(inp_shape)
                    im = model(inp, grid)
                    pred = torch.cat((pred, im), -2)
                    xx = torch.cat((xx[..., 1:, :], im), dim=-2)  # noqa: PLW2901

                (
                    _err_RMSE,
                    _err_nRMSE,
                    _err_CSV,
                    _err_Max,
                    _err_BD,
                    _err_F,
                ) = metric_func(
                    pred,
                    yy,
                    if_mean=True,
                    Lx=Lx,
                    Ly=Ly,
                    Lz=Lz,
                    initial_step=initial_step,
                )
                if itot == 0:
                    err_RMSE, err_nRMSE, err_CSV, err_Max, err_BD, err_F = (
                        _err_RMSE,
                        _err_nRMSE,
                        _err_CSV,
                        _err_Max,
                        _err_BD,
                        _err_F,
                    )
                    pred_plot = pred[:1]
                    target_plot = yy[:1]
                    val_l2_time = torch.zeros(yy.shape[-2]).to(device)
                else:
                    err_RMSE += _err_RMSE
                    err_nRMSE += _err_nRMSE
                    err_CSV += _err_CSV
                    err_Max += _err_Max
                    err_BD += _err_BD
                    err_F += _err_F

                    mean_dim = list(range(len(yy.shape) - 2))
                    mean_dim.append(-1)
                    mean_dim = tuple(mean_dim)
                    val_l2_time += torch.sqrt(
                        torch.mean((pred - yy) ** 2, dim=mean_dim)
                    )

    err_RMSE = np.array(err_RMSE.data.cpu() / itot)
    err_nRMSE = np.array(err_nRMSE.data.cpu() / itot)
    err_CSV = np.array(err_CSV.data.cpu() / itot)
    err_Max = np.array(err_Max.data.cpu() / itot)
    err_BD = np.array(err_BD.data.cpu() / itot)
    err_F = np.array(err_F.data.cpu() / itot)
    logger.info(f"RMSE: {err_RMSE:.5f}")
    logger.info(f"normalized RMSE: {err_nRMSE:.5f}")
    logger.info(f"RMSE of conserved variables: {err_CSV:.5f}")
    logger.info(f"Maximum value of rms error: {err_Max:.5f}")
    logger.info(f"RMSE at boundaries: {err_BD:.5f}")
    logger.info(f"RMSE in Fourier space: {err_F}")

    val_l2_time = val_l2_time / itot

    return err_RMSE, err_nRMSE, err_CSV, err_Max, err_BD, err_F

# %%
xx, yy, grid = next(iter(train_loader))
xx, yy, grid = xx.to(device), yy.to(device), grid.to(device)

# %%
inp_shape = list(xx.shape[:-2]) + [-1]
inp = xx.reshape(inp_shape)
output = model(inp, grid)

# %%
from torchviz import make_dot
dot = make_dot(output, params=dict(model.named_parameters()))
dot.format = "png"
dot.render("model_forward_graph")
print("Saved as model_forward_graph.png")
# Out:
# Saved as model_forward_graph.png

# %%
for ep in range(start_epoch, epochs):
    model.train()
    t1 = default_timer()
    train_l2_step, train_l2_full = 0, 0

    for xx, yy, grid in train_loader:
        loss = 0
        xx, yy, grid = xx.to(device), yy.to(device), grid.to(device)
        pred = yy[..., :initial_step, :]
        inp_shape = list(xx.shape[:-2]) + [-1]

        for t in range(initial_step, t_train):
            inp = xx.reshape(inp_shape)
            y = yy[..., t : t + 1, :]
            im = model(inp, grid)
            _batch = im.size(0)
            loss += loss_fn(im.reshape(_batch, -1), y.reshape(_batch, -1))
            pred = torch.cat((pred, im), -2)
            xx = torch.cat((xx[..., 1:, :], im), dim=-2)

        train_l2_step += loss.item()
        _batch = yy.size(0)
        _yy = yy[..., :t_train, :]
        l2_full = loss_fn(pred.reshape(_batch, -1), _yy.reshape(_batch, -1))
        train_l2_full += l2_full.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    if ep % model_update == 0:
        val_l2_step, val_l2_full = 0, 0
        model.eval()
        with torch.no_grad():
            for xx, yy, grid in val_loader:
                loss = 0
                xx, yy, grid = xx.to(device), yy.to(device), grid.to(device)
                pred = yy[..., :initial_step, :]
                inp_shape = list(xx.shape[:-2]) + [-1]

                for t in range(initial_step, yy.shape[-2]):
                    inp = xx.reshape(inp_shape)
                    y = yy[..., t : t + 1, :]
                    im = model(inp, grid)
                    _batch = im.size(0)
                    loss += loss_fn(im.reshape(_batch, -1), y.reshape(_batch, -1))
                    pred = torch.cat((pred, im), -2)
                    xx = torch.cat((xx[..., 1:, :], im), dim=-2)

                val_l2_step += loss.item()
                _pred = pred[..., initial_step:t_train, :]
                _yy = yy[..., initial_step:t_train, :]
                val_l2_full += loss_fn(_pred.reshape(_batch, -1), _yy.reshape(_batch, -1)).item()

            if val_l2_full < loss_val_min:
                loss_val_min = val_l2_full
                torch.save(
                    {
                        "epoch": ep,
                        "model_state_dict": model.state_dict(),
                        "optimizer_state_dict": optimizer.state_dict(),
                        "loss": loss_val_min,
                    },
                    model_path,
                )
    t2 = default_timer()
    scheduler.step()
    print("epoch: {0}, loss: {1:.5f}, t2-t1: {2:.5f}, trainL2: {3:.5f}, testL2: {4:.5f}".format(ep, loss.item(), t2 - t1, train_l2_full, val_l2_full))

print("Training complete.")
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-62-d2b34eaa3200> in <cell line: 0>()
#      13             inp = xx.reshape(inp_shape)
#      14             y = yy[..., t : t + 1, :]
# ---> 15             im = model(inp, grid)
#      16             _batch = im.size(0)
#      17             loss += loss_fn(im.reshape(_batch, -1), y.reshape(_batch, -1))
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-45-80896aa92aab> in forward(self, x, grid)
#      45
#      46         # Forward pass through CNO
# ---> 47         out = self.model(inputs)
#      48
#      49         # Reshape back to expected output format: [batch, spatial, channels, 1]
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-45-80896aa92aab> in forward(self, x)
#     186         for i in range(self.N_layers):
#     187             # Apply ResNet & save result
# --> 188             y = self.res_nets[i](x, original_input)
#     189             skip.append(y)
#     190
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-44-a0b42219ba72> in forward(self, x, original_input)
#     170     def forward(self, x, original_input):
#     171         for block in self.res_blocks:
# --> 172             x = block(x, original_input)
#     173         return x
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-44-a0b42219ba72> in forward(self, x, original_input)
#     125
#     126         # Apply first DLGN layer
# --> 127         gate1 = self.gating1(original_input)
#     128         out = self.dlgn_layer1(out, gate1)
#     129
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-43-b9c60f999a2a> in forward(self, original_input)
#      47         x = self.gate_weights(x)
#      48         # Apply sigmoid activation with beta parameter
# ---> 49         return torch.sigmoid(self.beta * x)
#      50
#      51 class DLGN_Layer(nn.Module):
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 10.12 MiB is free. Process 14172 has 14.73 GiB memory in use. Of the allocated memory 14.38 GiB is allocated by PyTorch, and 238.69 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# Test run with batch size 50
# epoch: 0, loss: 0.63057, t2-t1: 463.56203, trainL2: 9.55097, testL2: 0.38045
# epoch: 1, loss: 0.55014, t2-t1: 460.28001, trainL2: 4.16928, testL2: 0.31352
# epoch: 2, loss: 0.13798, t2-t1: 459.41851, trainL2: 2.85387, testL2: 0.06545
# epoch: 3, loss: 0.09339, t2-t1: 460.18633, trainL2: 1.86878, testL2: 0.07487
# epoch: 4, loss: 0.04525, t2-t1: 462.79572, trainL2: 1.96279, testL2: 0.02735
# epoch: 5, loss: 0.03533, t2-t1: 460.98556, trainL2: 1.58974, testL2: 0.02083
# epoch: 6, loss: 0.06565, t2-t1: 460.80017, trainL2: 1.52914, testL2: 0.05132
# epoch: 7, loss: 0.04068, t2-t1: 458.44843, trainL2: 1.72168, testL2: 0.02438
# epoch: 8, loss: 0.04329, t2-t1: 459.96253, trainL2: 1.50155, testL2: 0.02675
# epoch: 9, loss: 0.05211, t2-t1: 455.91932, trainL2: 1.49865, testL2: 0.03940
